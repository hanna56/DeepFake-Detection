# %% [markdown]
# ## Preparation

# %% [markdown]
# ### (1) Import packages

# %%
import os
from typing import Tuple, List, Sequence, Callable

import cv2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import torch

from torch import nn, Tensor
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, ConcatDataset

# !pip install -U git+https://github.com/albu/albumentations
import albumentations as A
from albumentations.pytorch import ToTensorV2

import torch.nn.functional as F
from sklearn.model_selection import train_test_split

import time

#추가설치
# !pip install torch_optimizer
# !pip install timm
# !pip install -U git+https://github.com/lukemelas/EfficientNet-PyTorch
from efficientnet_pytorch import EfficientNet
import timm
# Out:
# Collecting git+https://github.com/albu/albumentations
#   Cloning https://github.com/albu/albumentations to /tmp/pip-req-build-wckn_j2u
#   Running command git clone -q https://github.com/albu/albumentations /tmp/pip-req-build-wckn_j2u
# Requirement already satisfied, skipping upgrade: numpy>=1.11.1 in /usr/local/lib/python3.7/dist-packages (from albumentations==1.0.0) (1.19.5)
# Requirement already satisfied, skipping upgrade: scipy in /usr/local/lib/python3.7/dist-packages (from albumentations==1.0.0) (1.4.1)
# Requirement already satisfied, skipping upgrade: scikit-image>=0.16.1 in /usr/local/lib/python3.7/dist-packages (from albumentations==1.0.0) (0.16.2)
# Requirement already satisfied, skipping upgrade: PyYAML in /usr/local/lib/python3.7/dist-packages (from albumentations==1.0.0) (3.13)
# Requirement already satisfied, skipping upgrade: opencv-python>=4.1.1 in /usr/local/lib/python3.7/dist-packages (from albumentations==1.0.0) (4.1.2.30)
# Requirement already satisfied, skipping upgrade: imageio>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image>=0.16.1->albumentations==1.0.0) (2.4.1)
# Requirement already satisfied, skipping upgrade: matplotlib!=3.0.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image>=0.16.1->albumentations==1.0.0) (3.2.2)
# Requirement already satisfied, skipping upgrade: networkx>=2.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image>=0.16.1->albumentations==1.0.0) (2.5.1)
# Requirement already satisfied, skipping upgrade: pillow>=4.3.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image>=0.16.1->albumentations==1.0.0) (7.1.2)
# Requirement already satisfied, skipping upgrade: PyWavelets>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image>=0.16.1->albumentations==1.0.0) (1.1.1)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.16.1->albumentations==1.0.0) (1.3.1)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.16.1->albumentations==1.0.0) (2.4.7)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.16.1->albumentations==1.0.0) (2.8.1)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.16.1->albumentations==1.0.0) (0.10.0)
# Requirement already satisfied, skipping upgrade: decorator<5,>=4.3 in /usr/local/lib/python3.7/dist-packages (from networkx>=2.0->scikit-image>=0.16.1->albumentations==1.0.0) (4.4.2)
# Requirement already satisfied, skipping upgrade: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.1->matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.16.1->albumentations==1.0.0) (1.15.0)
# Building wheels for collected packages: albumentations
#   Building wheel for albumentations (setup.py) ... done
#   Created wheel for albumentations: filename=albumentations-1.0.0-cp37-none-any.whl size=98151 sha256=048f78938b9cfee0de958e9fb1f318e0f25cb9101c3545761dcfaeaaefddd00b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-khxju0db/wheels/45/8b/e4/2837bbcf517d00732b8e394f8646f22b8723ac00993230188b
# Successfully built albumentations
# Installing collected packages: albumentations
#   Found existing installation: albumentations 0.1.12
#     Uninstalling albumentations-0.1.12:
#       Successfully uninstalled albumentations-0.1.12
# Successfully installed albumentations-1.0.0
# Collecting torch_optimizer
#   Downloading https://files.pythonhosted.org/packages/af/0f/bc49a0f714a1896b80f31db9ba82eebcb2bad9e0f5757184574f8ecfe2f1/torch_optimizer-0.1.0-py3-none-any.whl (72kB)
#      |████████████████████████████████| 81kB 7.1MB/s
# Collecting pytorch-ranger>=0.1.1
#   Downloading https://files.pythonhosted.org/packages/0d/70/12256257d861bbc3e176130d25be1de085ce7a9e60594064888a950f2154/pytorch_ranger-0.1.1-py3-none-any.whl
# Requirement already satisfied: torch>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from torch_optimizer) (1.8.1+cu101)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.1.0->torch_optimizer) (3.7.4.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch>=1.1.0->torch_optimizer) (1.19.5)
# Installing collected packages: pytorch-ranger, torch-optimizer
# Successfully installed pytorch-ranger-0.1.1 torch-optimizer-0.1.0
# Collecting timm
#   Downloading https://files.pythonhosted.org/packages/ee/08/1ccaf8d516935666b7fa5f6aaddf157c66208ea0c93bb847ae09f166354f/timm-0.4.9-py3-none-any.whl (346kB)
#      |████████████████████████████████| 348kB 14.4MB/s
# Requirement already satisfied: torch>=1.4 in /usr/local/lib/python3.7/dist-packages (from timm) (1.8.1+cu101)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from timm) (0.9.1+cu101)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch>=1.4->timm) (1.19.5)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.4->timm) (3.7.4.3)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.7/dist-packages (from torchvision->timm) (7.1.2)
# Installing collected packages: timm
# Successfully installed timm-0.4.9
# Collecting git+https://github.com/lukemelas/EfficientNet-PyTorch
#   Cloning https://github.com/lukemelas/EfficientNet-PyTorch to /tmp/pip-req-build-ds8jtdni
#   Running command git clone -q https://github.com/lukemelas/EfficientNet-PyTorch /tmp/pip-req-build-ds8jtdni
# Requirement already satisfied, skipping upgrade: torch in /usr/local/lib/python3.7/dist-packages (from efficientnet-pytorch==0.7.1) (1.8.1+cu101)
# Requirement already satisfied, skipping upgrade: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->efficientnet-pytorch==0.7.1) (3.7.4.3)
# Requirement already satisfied, skipping upgrade: numpy in /usr/local/lib/python3.7/dist-packages (from torch->efficientnet-pytorch==0.7.1) (1.19.5)
# Building wheels for collected packages: efficientnet-pytorch
#   Building wheel for efficientnet-pytorch (setup.py) ... done
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.7.1-cp37-none-any.whl size=20623 sha256=0ae3b535df42406950867aebd826c8ea20eb9fe54afc933aa53ac61522dd9cb8
#   Stored in directory: /tmp/pip-ephem-wheel-cache-g6exgy_r/wheels/bd/0a/9c/ed64b806609794458663ce25997b5061d661de86a882269ec4
# Successfully built efficientnet-pytorch
# Installing collected packages: efficientnet-pytorch
# Successfully installed efficientnet-pytorch-0.7.1

# %% [markdown]
# ### (2) Google Drive Colab 연결

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
os.chdir('/content/drive/MyDrive/statml_competition/')

# %% [markdown]
# ### (3) Setting

# %%
if torch.cuda.is_available():
  device = torch.device('cuda:0')
else:
  device = torch.device('cpu')

print('using device:', device)
# Out:
# using device: cuda:0

# %%
device = "cuda:0"
dtype = torch.float
ltype = torch.long # entropy

# %%
# fake 1, real 0 로 사용
train_df = pd.read_csv('./face_image/face_images.csv')
train_df.head()
# Out:
#                                path  real  fake
# 0  ./face_image/fake/JFH50GFJUL.jpg     0     1
# 1  ./face_image/fake/0VPS5TI60G.jpg     0     1
# 2       ./face_image/real/61911.jpg     1     0
# 3  ./face_image/fake/APADHGXN31.jpg     0     1
# 4  ./face_image/fake/SJO2UL69C2.jpg     0     1

# %%
print(train_df.shape)
# Out:
# (20000, 3)

# %% [markdown]
# # random seed 고정
# 참고 : https://dacon.io/codeshare/2363?dtype=recent

# %%
import random
SEED = 42

def seed_everything(seed):
    random.seed(seed)
    np.random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = True

seed_everything(SEED)

# %% [markdown]
# ## 커스텀 데이터 정의

# %%
class FaceDataset(Dataset):
  def __init__(self, image_label, transforms) :
    self.df = image_label
    self.transforms = transforms
        
  def __len__(self) -> int:
    return self.df.shape[0]

  def __getitem__(self, index: int) -> Tuple[Tensor]:
    assert index <= len(self), 'index range error' 
      
    image_dir = self.df.iloc[index, ]['path']
    image_id = self.df.iloc[index, ]['fake'].astype(np.int64)
    
    image =  cv2.imread(image_dir, cv2.COLOR_BGR2RGB)
    target = torch.as_tensor(image_id, dtype=torch.long)

    if self.transforms is not None :
      image = self.transforms(image=image)['image']

    image = image/255.0
    
    return image, target

class TestDataset(Dataset):
  def __init__(self, image, transforms) :
    self.image = image
    self.transforms = transforms
        
  def __len__(self) -> int:
    return len(self.image)

  def __getitem__(self, index: int) -> Tuple[Tensor]:
    assert index <= len(self), 'index range error' 
    
    image_name = self.image[index]
    image_dir = './face_image/test_v1.1/' + image_name

    image =  cv2.imread(image_dir, cv2.COLOR_BGR2RGB)
    
    if self.transforms is not None :
      image = self.transforms(image=image)['image']
    image = image/255.0

    return image_name, image

# %% [markdown]
# ## 이미지 어그멘테이션
# ( 참고 : https://github.com/albumentations-team/albumentations )

# %%
transforms_tr = A.Compose([
    A.Resize(128, 128),
    ToTensorV2(), ])

transforms_val = A.Compose([
    A.Resize(128, 128),
    ToTensorV2(), ])

# %% [markdown]
# #Resnet 18-50 ensemble
#
# 참고 자료: https://deep-learning-study.tistory.com/534

# %%
class BasicBlock(nn.Module):
    expansion = 1
    def __init__(self, in_channels, out_channels, stride=1):
        super().__init__()

        # BatchNorm에 bias가 포함되어 있으므로, conv2d는 bias=False로 설정합니다.
        self.residual_function = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=stride, padding=1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(),
            nn.Conv2d(out_channels, out_channels * BasicBlock.expansion, kernel_size=3, stride=1, padding=1, bias=False),
            nn.BatchNorm2d(out_channels * BasicBlock.expansion),
        )

        # identity mapping, input과 output의 feature map size, filter 수가 동일한 경우 사용.
        self.shortcut = nn.Sequential()

        self.relu = nn.ReLU()

        # projection mapping using 1x1conv
        if stride != 1 or in_channels != BasicBlock.expansion * out_channels:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channels, out_channels * BasicBlock.expansion, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(out_channels * BasicBlock.expansion)
            )

    def forward(self, x):
        x = self.residual_function(x) + self.shortcut(x)
        x = self.relu(x)
        return x


class BottleNeck(nn.Module):
    expansion = 4
    def __init__(self, in_channels, out_channels, stride=1):
        super().__init__()

        self.residual_function = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(),
            nn.Conv2d(out_channels, out_channels, kernel_size=3, stride=stride, padding=1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(),
            nn.Conv2d(out_channels, out_channels * BottleNeck.expansion, kernel_size=1, stride=1, bias=False),
            nn.BatchNorm2d(out_channels * BottleNeck.expansion),
        )

        self.shortcut = nn.Sequential()

        self.relu = nn.ReLU()

        if stride != 1 or in_channels != out_channels * BottleNeck.expansion:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channels, out_channels*BottleNeck.expansion, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(out_channels*BottleNeck.expansion)
            )
            
    def forward(self, x):
        x = self.residual_function(x) + self.shortcut(x)
        x = self.relu(x)
        return x

# %%
class ResNet(nn.Module):
    def __init__(self, block, num_block, num_classes=10, init_weights=True):
        super().__init__()

        self.in_channels=64

        self.conv1 = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=7, stride=2, padding=3, bias=False),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=3, stride=2, padding=1)
        )

        self.conv2_x = self._make_layer(block, 64, num_block[0], 1)
        self.conv3_x = self._make_layer(block, 128, num_block[1], 2)
        self.conv4_x = self._make_layer(block, 256, num_block[2], 2)
        self.conv5_x = self._make_layer(block, 512, num_block[3], 2)

        self.avg_pool = nn.AdaptiveAvgPool2d((1,1))
        self.fc = nn.Linear(512 * block.expansion, num_classes)

        #weights inittialization
        if init_weights:
            self._initialize_weights()

    def _make_layer(self, block, out_channels, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_channels, out_channels, stride))
            self.in_channels = out_channels * block.expansion

        return nn.Sequential(*layers)

    def forward(self,x):
        output = self.conv1(x)
        output = self.conv2_x(output)
        x = self.conv3_x(output)
        x = self.conv4_x(x)
        x = self.conv5_x(x)
        x = self.avg_pool(x)
        x = x.view(x.size(0), -1)
        x = self.fc(x)
        return x

    # define weight initialization function
    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.BatchNorm2d):
                nn.init.constant_(m.weight, 1)
                nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.Linear):
                nn.init.normal_(m.weight, 0, 0.01)
                nn.init.constant_(m.bias, 0)

def resnet18():
    return ResNet(BasicBlock, [2,2,2,2])

def resnet34():
    return ResNet(BasicBlock, [3, 4, 6, 3])

def resnet50():
    return ResNet(BottleNeck, [3,4,6,3])

def resnet101():
    return ResNet(BottleNeck, [3, 4, 23, 3])

def resnet152():
    return ResNet(BottleNeck, [3, 8, 36, 3])

# %%
class MyEnsemble(nn.Module):
    def __init__(self, modelA, modelB, nb_classes=10):
        super(MyEnsemble, self).__init__()
        self.modelA = modelA
        self.modelB = modelB
    
        # Remove last linear layer
        self.modelA.fc = nn.Identity()
        self.modelB.fc = nn.Identity()
        
        # Create new classifier
        self.classifier = nn.Linear(2048+512, nb_classes)
        
    def forward(self, x):
        x1 = self.modelA(x.clone())  # clone to make sure x is not changed by inplace methods
        x1 = x1.view(x1.size(0), -1)
        x2 = self.modelB(x)
        x2 = x2.view(x2.size(0), -1)
        x = torch.cat((x1, x2), dim=1)
        
        x = self.classifier(F.relu(x))
        return x

modelA = resnet18().to(device)
modelB = resnet50().to(device)

# %%
num_epochs = 30
EARLY_STOPPING_EPOCH = 5
SEED=42

from sklearn.model_selection import KFold
kfold=KFold(n_splits=5, shuffle=True, random_state=SEED) #5-fold

resnet_models=[] #각 fold의 best model을 담을 리스트 

for fold_index, (trn_idx, val_idx) in enumerate(kfold.split(train_df),1):
  print('[fold: %d]' % fold_index)

  torch.cuda.empty_cache()

  train=train_df.iloc[trn_idx]
  valid=train_df.iloc[val_idx]

  tr_dataset=FaceDataset(image_label=train, transforms=transforms_tr)
  val_dataset=FaceDataset(image_label=valid, transforms=transforms_val)

  train_loader=DataLoader(tr_dataset, batch_size=64, shuffle=True, num_workers=8)
  valid_loader=DataLoader(val_dataset, batch_size=64, shuffle=True, num_workers=8)

  #모델 정의
  model = MyEnsemble(modelA, modelB)
  model.to(device)

  optimizer = optim.Adam(model.parameters(), lr=7e-4, weight_decay=0) #l2 reg 적용
  lr_sched = optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.1) 

  valid_early_stop = 0
  valid_best_loss = float('inf')
  since = time.time()

  final_train_loss = []
  final_train_acc = []
  final_valid_loss = []
  final_valid_acc = []

  for e in range(num_epochs) :
    print(f' ====================== epoch %d ======================' % (e+1) )
    train_loss_list = []
    train_acc_list = []

    # train
    model.train()
    for i, (images, targets) in enumerate(train_loader) : 
      optimizer.zero_grad()
      
      images = images.to(device, dtype)
      targets = targets.to(device, ltype)
    
      scores = model(images)
      _, preds = scores.max(dim=1)

      loss = F.cross_entropy(scores, targets)
      loss.backward()
      optimizer.step()
      
      correct = sum(targets == preds).cpu()
      acc=(correct/64 * 100)

      train_loss_list.append(loss)
      train_acc_list.append(acc)

      if i % 20 == 0 :
        print(f'Iteration %3.d | Train Loss  %.4f | Classifier Accuracy %2.2f' % (i, loss, acc))

    train_mean_loss = np.mean(train_loss_list, dtype="float64")
    train_mean_acc = np.mean(train_acc_list, dtype="float64")

    final_train_loss.append(train_mean_loss)
    final_train_acc.append(train_mean_acc)
    
    epoch_time = time.time() - since
    since = time.time()

    print('')
    print(f'[Summary] Elapsed time : %.0f m %.0f s' % (epoch_time // 60, epoch_time % 60))
    print(f'Train Loss Mean %.4f | Accuracy %2.2f ' % (train_mean_loss, train_mean_acc) )

    # validation 
    model.eval()
    valid_loss_list = []
    valid_acc_list = []
    for i, (images, targets) in enumerate(valid_loader) : 
      optimizer.zero_grad()
      images = images.to(device=device, dtype=dtype)
      targets = targets.to(device=device, dtype=ltype)

      with torch.no_grad():
        scores = model(images)
        loss = F.cross_entropy(scores, targets)
        _, preds = scores.max(dim=1)
      
      correct = sum(targets == preds).cpu()
      acc=(correct/64 * 100)

      valid_loss_list.append(loss)
      valid_acc_list.append(acc)
  
    val_mean_loss = np.mean(valid_loss_list, dtype="float64")
    val_mean_acc = np.mean(valid_acc_list, dtype="float64")

    final_valid_loss.append(val_mean_loss)
    final_valid_acc.append(val_mean_acc)

    print(f'Valid Loss Mean %.4f | Accuracy %2.2f ' % (val_mean_loss, val_mean_acc) )
    print('')

    if val_mean_loss < valid_best_loss:
      valid_best_loss = val_mean_loss
      valid_early_stop = 0
      # new best model save (valid 기준)
      best_model = model
      if (e+1) == num_epochs:
        resnet_models.append(best_model)
      

    else:
      # early stopping    
      valid_early_stop += 1
      if valid_early_stop >= EARLY_STOPPING_EPOCH:
        print("EARLY STOPPING!!")
        resnet_models.append(best_model)
        break

    lr_sched.step()
# Out:
# [fold: 1]
#  ====================== epoch 1 ======================
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Iteration   0 | Train Loss  2.1438 | Classifier Accuracy 12.50
# Iteration  20 | Train Loss  0.6735 | Classifier Accuracy 57.81
# Iteration  40 | Train Loss  0.4896 | Classifier Accuracy 75.00
# Iteration  60 | Train Loss  0.5552 | Classifier Accuracy 70.31
# Iteration  80 | Train Loss  0.6521 | Classifier Accuracy 64.06
# Iteration 100 | Train Loss  0.5947 | Classifier Accuracy 71.88
# Iteration 120 | Train Loss  0.3955 | Classifier Accuracy 75.00
# Iteration 140 | Train Loss  0.6125 | Classifier Accuracy 71.88
# Iteration 160 | Train Loss  0.4911 | Classifier Accuracy 78.12
# Iteration 180 | Train Loss  0.4794 | Classifier Accuracy 75.00
# Iteration 200 | Train Loss  0.5912 | Classifier Accuracy 71.88
# Iteration 220 | Train Loss  0.4456 | Classifier Accuracy 81.25
# Iteration 240 | Train Loss  0.4918 | Classifier Accuracy 79.69
#
# [Summary] Elapsed time : 16 m 18 s
# Train Loss Mean 0.6232 | Accuracy 68.89
# Valid Loss Mean 0.5230 | Accuracy 73.19
#
#  ====================== epoch 2 ======================
# Iteration   0 | Train Loss  0.4640 | Classifier Accuracy 75.00
# Iteration  20 | Train Loss  0.3529 | Classifier Accuracy 87.50
# Iteration  40 | Train Loss  0.4372 | Classifier Accuracy 79.69
# Iteration  60 | Train Loss  0.4730 | Classifier Accuracy 82.81
# Iteration  80 | Train Loss  0.5603 | Classifier Accuracy 73.44
# Iteration 100 | Train Loss  0.5831 | Classifier Accuracy 73.44
# Iteration 120 | Train Loss  0.5369 | Classifier Accuracy 73.44
# Iteration 140 | Train Loss  0.4883 | Classifier Accuracy 75.00
# Iteration 160 | Train Loss  0.4144 | Classifier Accuracy 78.12
# Iteration 180 | Train Loss  0.4112 | Classifier Accuracy 81.25
# Iteration 200 | Train Loss  0.3838 | Classifier Accuracy 84.38
# Iteration 220 | Train Loss  0.5042 | Classifier Accuracy 75.00
# Iteration 240 | Train Loss  0.3090 | Classifier Accuracy 84.38
#
# [Summary] Elapsed time : 3 m 56 s
# Train Loss Mean 0.4339 | Accuracy 80.51
# Valid Loss Mean 0.3851 | Accuracy 82.04
#
#  ====================== epoch 3 ======================
# Iteration   0 | Train Loss  0.3725 | Classifier Accuracy 84.38
# Iteration  20 | Train Loss  0.3053 | Classifier Accuracy 87.50
# Iteration  40 | Train Loss  0.5450 | Classifier Accuracy 79.69
# Iteration  60 | Train Loss  0.2205 | Classifier Accuracy 90.62
# Iteration  80 | Train Loss  0.2350 | Classifier Accuracy 90.62
# Iteration 100 | Train Loss  0.4009 | Classifier Accuracy 84.38
# Iteration 120 | Train Loss  0.4974 | Classifier Accuracy 79.69
# Iteration 140 | Train Loss  0.2254 | Classifier Accuracy 87.50
# Iteration 160 | Train Loss  0.3805 | Classifier Accuracy 81.25
# Iteration 180 | Train Loss  0.2573 | Classifier Accuracy 89.06
# Iteration 200 | Train Loss  0.2995 | Classifier Accuracy 85.94
# Iteration 220 | Train Loss  0.2799 | Classifier Accuracy 92.19
# Iteration 240 | Train Loss  0.3541 | Classifier Accuracy 85.94
#
# [Summary] Elapsed time : 0 m 40 s
# Train Loss Mean 0.3116 | Accuracy 86.84
# Valid Loss Mean 0.4852 | Accuracy 77.88
#
#  ====================== epoch 4 ======================
# Iteration   0 | Train Loss  0.3386 | Classifier Accuracy 84.38
# Iteration  20 | Train Loss  0.2090 | Classifier Accuracy 90.62
# Iteration  40 | Train Loss  0.2187 | Classifier Accuracy 90.62
# Iteration  60 | Train Loss  0.1950 | Classifier Accuracy 90.62
# Iteration  80 | Train Loss  0.2411 | Classifier Accuracy 90.62
# Iteration 100 | Train Loss  0.2202 | Classifier Accuracy 92.19
# Iteration 120 | Train Loss  0.1302 | Classifier Accuracy 96.88
# Iteration 140 | Train Loss  0.1841 | Classifier Accuracy 93.75
# Iteration 160 | Train Loss  0.2162 | Classifier Accuracy 90.62
# Iteration 180 | Train Loss  0.1309 | Classifier Accuracy 95.31
# Iteration 200 | Train Loss  0.2110 | Classifier Accuracy 93.75
# Iteration 220 | Train Loss  0.2524 | Classifier Accuracy 92.19
# Iteration 240 | Train Loss  0.1675 | Classifier Accuracy 93.75
#
# [Summary] Elapsed time : 0 m 39 s
# Train Loss Mean 0.2397 | Accuracy 90.29
# Valid Loss Mean 0.3371 | Accuracy 85.07
#
#  ====================== epoch 5 ======================
# Iteration   0 | Train Loss  0.1477 | Classifier Accuracy 92.19
# Iteration  20 | Train Loss  0.0995 | Classifier Accuracy 96.88
# Iteration  40 | Train Loss  0.2346 | Classifier Accuracy 89.06
# Iteration  60 | Train Loss  0.2308 | Classifier Accuracy 93.75
# Iteration  80 | Train Loss  0.0684 | Classifier Accuracy 96.88
# Iteration 100 | Train Loss  0.2359 | Classifier Accuracy 89.06
# Iteration 120 | Train Loss  0.0786 | Classifier Accuracy 96.88
# Iteration 140 | Train Loss  0.0887 | Classifier Accuracy 93.75
# Iteration 160 | Train Loss  0.1432 | Classifier Accuracy 92.19
# Iteration 180 | Train Loss  0.1577 | Classifier Accuracy 92.19
# Iteration 200 | Train Loss  0.1153 | Classifier Accuracy 95.31
# Iteration 220 | Train Loss  0.2250 | Classifier Accuracy 90.62
# Iteration 240 | Train Loss  0.1237 | Classifier Accuracy 93.75
#
# [Summary] Elapsed time : 0 m 41 s
# Train Loss Mean 0.1599 | Accuracy 93.69
# Valid Loss Mean 0.7134 | Accuracy 74.65
#
#  ====================== epoch 6 ======================
# Iteration   0 | Train Loss  0.1824 | Classifier Accuracy 92.19
# Iteration  20 | Train Loss  0.0607 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0693 | Classifier Accuracy 96.88
# Iteration  60 | Train Loss  0.0167 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0814 | Classifier Accuracy 96.88
# Iteration 100 | Train Loss  0.0901 | Classifier Accuracy 98.44
# Iteration 120 | Train Loss  0.0233 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0467 | Classifier Accuracy 96.88
# Iteration 160 | Train Loss  0.0240 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0292 | Classifier Accuracy 98.44
# Iteration 200 | Train Loss  0.0407 | Classifier Accuracy 100.00
# Iteration 220 | Train Loss  0.0161 | Classifier Accuracy 100.00
# Iteration 240 | Train Loss  0.0537 | Classifier Accuracy 98.44
#
# [Summary] Elapsed time : 0 m 39 s
# Train Loss Mean 0.0543 | Accuracy 98.20
# Valid Loss Mean 0.2194 | Accuracy 91.12
#
#  ====================== epoch 7 ======================
# Iteration   0 | Train Loss  0.0133 | Classifier Accuracy 100.00
# Iteration  20 | Train Loss  0.0220 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0065 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0184 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0197 | Classifier Accuracy 100.00
# Iteration 100 | Train Loss  0.0127 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0064 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0119 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.0098 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0135 | Classifier Accuracy 100.00
# Iteration 200 | Train Loss  0.0298 | Classifier Accuracy 98.44
# Iteration 220 | Train Loss  0.0143 | Classifier Accuracy 100.00
# Iteration 240 | Train Loss  0.0131 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 0 m 39 s
# Train Loss Mean 0.0177 | Accuracy 99.67
# Valid Loss Mean 0.2354 | Accuracy 91.72
#
#  ====================== epoch 8 ======================
# Iteration   0 | Train Loss  0.0081 | Classifier Accuracy 100.00
# Iteration  20 | Train Loss  0.0040 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0034 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0057 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0170 | Classifier Accuracy 98.44
# Iteration 100 | Train Loss  0.0021 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0056 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0081 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.0030 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0190 | Classifier Accuracy 100.00
# Iteration 200 | Train Loss  0.0036 | Classifier Accuracy 100.00
# Iteration 220 | Train Loss  0.0017 | Classifier Accuracy 100.00
# Iteration 240 | Train Loss  0.0032 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 0 m 39 s
# Train Loss Mean 0.0074 | Accuracy 99.91
# Valid Loss Mean 0.2440 | Accuracy 91.54
#
#  ====================== epoch 9 ======================
# Iteration   0 | Train Loss  0.0030 | Classifier Accuracy 100.00
# Iteration  20 | Train Loss  0.0040 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0021 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0093 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0066 | Classifier Accuracy 100.00
# Iteration 100 | Train Loss  0.0036 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0009 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0077 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.0015 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0073 | Classifier Accuracy 100.00
# Iteration 200 | Train Loss  0.0012 | Classifier Accuracy 100.00
# Iteration 220 | Train Loss  0.0016 | Classifier Accuracy 100.00
# Iteration 240 | Train Loss  0.0021 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 0 m 38 s
# Train Loss Mean 0.0041 | Accuracy 99.97
# Valid Loss Mean 0.2548 | Accuracy 91.52
#
#  ====================== epoch 10 ======================
# Iteration   0 | Train Loss  0.0012 | Classifier Accuracy 100.00
# Iteration  20 | Train Loss  0.0029 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0017 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0014 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0014 | Classifier Accuracy 100.00
# Iteration 100 | Train Loss  0.0026 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0014 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0022 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.0010 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0066 | Classifier Accuracy 100.00
# Iteration 200 | Train Loss  0.0021 | Classifier Accuracy 100.00
# Iteration 220 | Train Loss  0.0010 | Classifier Accuracy 100.00
# Iteration 240 | Train Loss  0.0015 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 0 m 39 s
# Train Loss Mean 0.0028 | Accuracy 99.97
# Valid Loss Mean 0.2714 | Accuracy 91.49
#
#  ====================== epoch 11 ======================
# Iteration   0 | Train Loss  0.0005 | Classifier Accuracy 100.00
# Iteration  20 | Train Loss  0.0015 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0016 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0014 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0012 | Classifier Accuracy 100.00
# Iteration 100 | Train Loss  0.0012 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0014 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0008 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.0016 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0025 | Classifier Accuracy 100.00
# Iteration 200 | Train Loss  0.0011 | Classifier Accuracy 100.00
# Iteration 220 | Train Loss  0.0007 | Classifier Accuracy 100.00
# Iteration 240 | Train Loss  0.0012 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 0 m 39 s
# Train Loss Mean 0.0023 | Accuracy 99.99
# Valid Loss Mean 0.2709 | Accuracy 91.64
#
# EARLY STOPPING!!
# [fold: 2]
#  ====================== epoch 1 ======================
# Iteration   0 | Train Loss  2.8193 | Classifier Accuracy 0.00
# Iteration  20 | Train Loss  0.2283 | Classifier Accuracy 92.19
# Iteration  40 | Train Loss  0.1032 | Classifier Accuracy 95.31
# Iteration  60 | Train Loss  0.2416 | Classifier Accuracy 87.50
# Iteration  80 | Train Loss  0.2925 | Classifier Accuracy 90.62
# Iteration 100 | Train Loss  0.1639 | Classifier Accuracy 92.19
# Iteration 120 | Train Loss  0.1515 | Classifier Accuracy 96.88
# Iteration 140 | Train Loss  0.2989 | Classifier Accuracy 89.06
# Iteration 160 | Train Loss  0.1435 | Classifier Accuracy 93.75
# Iteration 180 | Train Loss  0.2249 | Classifier Accuracy 90.62
# Iteration 200 | Train Loss  0.1951 | Classifier Accuracy 92.19
# Iteration 220 | Train Loss  0.1459 | Classifier Accuracy 95.31
# Iteration 240 | Train Loss  0.0967 | Classifier Accuracy 95.31
#
# [Summary] Elapsed time : 0 m 31 s
# Train Loss Mean 0.1998 | Accuracy 92.43
# Valid Loss Mean 0.1289 | Accuracy 94.00
#
#  ====================== epoch 2 ======================
# Iteration   0 | Train Loss  0.0498 | Classifier Accuracy 98.44
# Iteration  20 | Train Loss  0.2099 | Classifier Accuracy 96.88
# Iteration  40 | Train Loss  0.0657 | Classifier Accuracy 96.88
# Iteration  60 | Train Loss  0.1716 | Classifier Accuracy 92.19
# Iteration  80 | Train Loss  0.0488 | Classifier Accuracy 98.44
# Iteration 100 | Train Loss  0.1006 | Classifier Accuracy 95.31
# Iteration 120 | Train Loss  0.1394 | Classifier Accuracy 92.19
# Iteration 140 | Train Loss  0.0732 | Classifier Accuracy 95.31
# Iteration 160 | Train Loss  0.2160 | Classifier Accuracy 93.75
# Iteration 180 | Train Loss  0.1135 | Classifier Accuracy 93.75
# Iteration 200 | Train Loss  0.2178 | Classifier Accuracy 89.06
# Iteration 220 | Train Loss  0.1255 | Classifier Accuracy 93.75
# Iteration 240 | Train Loss  0.0548 | Classifier Accuracy 98.44
#
# [Summary] Elapsed time : 0 m 38 s
# Train Loss Mean 0.1137 | Accuracy 95.66
# Valid Loss Mean 0.1499 | Accuracy 93.90
#
#  ====================== epoch 3 ======================
# Iteration   0 | Train Loss  0.0880 | Classifier Accuracy 93.75
# Iteration  20 | Train Loss  0.0187 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0877 | Classifier Accuracy 98.44
# Iteration  60 | Train Loss  0.2774 | Classifier Accuracy 89.06
# Iteration  80 | Train Loss  0.0233 | Classifier Accuracy 100.00
# Iteration 100 | Train Loss  0.0671 | Classifier Accuracy 96.88
# Iteration 120 | Train Loss  0.0933 | Classifier Accuracy 96.88
# Iteration 140 | Train Loss  0.0619 | Classifier Accuracy 98.44
# Iteration 160 | Train Loss  0.0319 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0562 | Classifier Accuracy 96.88
# Iteration 200 | Train Loss  0.0320 | Classifier Accuracy 98.44
# Iteration 220 | Train Loss  0.0451 | Classifier Accuracy 98.44
# Iteration 240 | Train Loss  0.0722 | Classifier Accuracy 96.88
#
# [Summary] Elapsed time : 0 m 39 s
# Train Loss Mean 0.0882 | Accuracy 96.61
# Valid Loss Mean 0.2242 | Accuracy 91.20
#
#  ====================== epoch 4 ======================
# Iteration   0 | Train Loss  0.0635 | Classifier Accuracy 98.44
# Iteration  20 | Train Loss  0.0606 | Classifier Accuracy 96.88
# Iteration  40 | Train Loss  0.0566 | Classifier Accuracy 98.44
# Iteration  60 | Train Loss  0.0268 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0986 | Classifier Accuracy 95.31
# Iteration 100 | Train Loss  0.0961 | Classifier Accuracy 98.44
# Iteration 120 | Train Loss  0.0147 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0679 | Classifier Accuracy 98.44
# Iteration 160 | Train Loss  0.1225 | Classifier Accuracy 95.31
# Iteration 180 | Train Loss  0.0690 | Classifier Accuracy 96.88
# Iteration 200 | Train Loss  0.0582 | Classifier Accuracy 96.88
# Iteration 220 | Train Loss  0.0216 | Classifier Accuracy 98.44
# Iteration 240 | Train Loss  0.0662 | Classifier Accuracy 96.88
#
# [Summary] Elapsed time : 0 m 39 s
# Train Loss Mean 0.0581 | Accuracy 97.94
# Valid Loss Mean 0.1967 | Accuracy 92.39
#
#  ====================== epoch 5 ======================
# Iteration   0 | Train Loss  0.0760 | Classifier Accuracy 93.75
# Iteration  20 | Train Loss  0.0327 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.2586 | Classifier Accuracy 90.62
# Iteration  60 | Train Loss  0.0573 | Classifier Accuracy 96.88
# Iteration  80 | Train Loss  0.0200 | Classifier Accuracy 100.00
# Iteration 100 | Train Loss  0.0308 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0424 | Classifier Accuracy 96.88
# Iteration 140 | Train Loss  0.0134 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.1751 | Classifier Accuracy 96.88
# Iteration 180 | Train Loss  0.0173 | Classifier Accuracy 98.44
# Iteration 200 | Train Loss  0.0293 | Classifier Accuracy 98.44
# Iteration 220 | Train Loss  0.0714 | Classifier Accuracy 96.88
# Iteration 240 | Train Loss  0.0493 | Classifier Accuracy 98.44
#
# [Summary] Elapsed time : 0 m 39 s
# Train Loss Mean 0.0623 | Accuracy 97.52
# Valid Loss Mean 0.1837 | Accuracy 93.35
#
#  ====================== epoch 6 ======================
# Iteration   0 | Train Loss  0.1083 | Classifier Accuracy 95.31
# Iteration  20 | Train Loss  0.0406 | Classifier Accuracy 98.44
# Iteration  40 | Train Loss  0.0146 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0416 | Classifier Accuracy 98.44
# Iteration  80 | Train Loss  0.0041 | Classifier Accuracy 100.00
# Iteration 100 | Train Loss  0.0032 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0042 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0271 | Classifier Accuracy 98.44
# Iteration 160 | Train Loss  0.0054 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0089 | Classifier Accuracy 100.00
# Iteration 200 | Train Loss  0.0131 | Classifier Accuracy 100.00
# Iteration 220 | Train Loss  0.0073 | Classifier Accuracy 100.00
# Iteration 240 | Train Loss  0.0044 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 0 m 39 s
# Train Loss Mean 0.0184 | Accuracy 99.34
# Valid Loss Mean 0.1093 | Accuracy 95.76
#
#  ====================== epoch 7 ======================
# Iteration   0 | Train Loss  0.0061 | Classifier Accuracy 100.00
# Iteration  20 | Train Loss  0.0027 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0049 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0079 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0007 | Classifier Accuracy 100.00
# Iteration 100 | Train Loss  0.0078 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0011 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0012 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.0070 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0018 | Classifier Accuracy 100.00
# Iteration 200 | Train Loss  0.0056 | Classifier Accuracy 100.00
# Iteration 220 | Train Loss  0.0041 | Classifier Accuracy 100.00
# Iteration 240 | Train Loss  0.0063 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 0 m 38 s
# Train Loss Mean 0.0046 | Accuracy 99.94
# Valid Loss Mean 0.1039 | Accuracy 95.91
#
#  ====================== epoch 8 ======================
# Iteration   0 | Train Loss  0.0025 | Classifier Accuracy 100.00
# Iteration  20 | Train Loss  0.0010 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0018 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0028 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0011 | Classifier Accuracy 100.00
# Iteration 100 | Train Loss  0.0005 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0005 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0008 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.0040 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0071 | Classifier Accuracy 100.00
# Iteration 200 | Train Loss  0.0008 | Classifier Accuracy 100.00
# Iteration 220 | Train Loss  0.0010 | Classifier Accuracy 100.00
# Iteration 240 | Train Loss  0.0005 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 0 m 39 s
# Train Loss Mean 0.0023 | Accuracy 99.99
# Valid Loss Mean 0.1048 | Accuracy 95.91
#
#  ====================== epoch 9 ======================
# Iteration   0 | Train Loss  0.0018 | Classifier Accuracy 100.00
# Iteration  20 | Train Loss  0.0017 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0010 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0008 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0013 | Classifier Accuracy 100.00
# Iteration 100 | Train Loss  0.0003 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0012 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0005 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.0004 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0006 | Classifier Accuracy 100.00
# Iteration 200 | Train Loss  0.0022 | Classifier Accuracy 100.00
# Iteration 220 | Train Loss  0.0003 | Classifier Accuracy 100.00
# Iteration 240 | Train Loss  0.0007 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 0 m 39 s
# Train Loss Mean 0.0014 | Accuracy 100.00
# Valid Loss Mean 0.1055 | Accuracy 96.03
#
#  ====================== epoch 10 ======================
# Iteration   0 | Train Loss  0.0010 | Classifier Accuracy 100.00
# Iteration  20 | Train Loss  0.0006 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0008 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0013 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0006 | Classifier Accuracy 100.00
# Iteration 100 | Train Loss  0.0008 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0015 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0140 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.0006 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0009 | Classifier Accuracy 100.00
# Iteration 200 | Train Loss  0.0004 | Classifier Accuracy 100.00
# Iteration 220 | Train Loss  0.0009 | Classifier Accuracy 100.00
# Iteration 240 | Train Loss  0.0008 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 0 m 39 s
# Train Loss Mean 0.0010 | Accuracy 100.00
# Valid Loss Mean 0.1055 | Accuracy 96.03
#
#  ====================== epoch 11 ======================
# Iteration   0 | Train Loss  0.0004 | Classifier Accuracy 100.00
# Iteration  20 | Train Loss  0.0005 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0023 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0009 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0029 | Classifier Accuracy 100.00
# Iteration 100 | Train Loss  0.0023 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0011 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0032 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.0007 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0010 | Classifier Accuracy 100.00
# Iteration 200 | Train Loss  0.0004 | Classifier Accuracy 100.00
# Iteration 220 | Train Loss  0.0026 | Classifier Accuracy 100.00
# Iteration 240 | Train Loss  0.0007 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 0 m 38 s
# Train Loss Mean 0.0011 | Accuracy 99.99
# Valid Loss Mean 0.1087 | Accuracy 96.11
#
#  ====================== epoch 12 ======================
# Iteration   0 | Train Loss  0.0003 | Classifier Accuracy 100.00
# Iteration  20 | Train Loss  0.0005 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0004 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0001 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0004 | Classifier Accuracy 100.00
# Iteration 100 | Train Loss  0.0002 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0002 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0003 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.0056 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0004 | Classifier Accuracy 100.00
# Iteration 200 | Train Loss  0.0004 | Classifier Accuracy 100.00
# Iteration 220 | Train Loss  0.0007 | Classifier Accuracy 100.00
# Iteration 240 | Train Loss  0.0006 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 0 m 39 s
# Train Loss Mean 0.0007 | Accuracy 100.00
# Valid Loss Mean 0.1078 | Accuracy 95.96
#
# EARLY STOPPING!!
# [fold: 3]
#  ====================== epoch 1 ======================
# Iteration   0 | Train Loss  2.3058 | Classifier Accuracy 0.00
# Iteration  20 | Train Loss  0.0604 | Classifier Accuracy 96.88
# Iteration  40 | Train Loss  0.1152 | Classifier Accuracy 96.88
# Iteration  60 | Train Loss  0.0732 | Classifier Accuracy 95.31
# Iteration  80 | Train Loss  0.0449 | Classifier Accuracy 98.44
# Iteration 100 | Train Loss  0.0711 | Classifier Accuracy 98.44
# Iteration 120 | Train Loss  0.0968 | Classifier Accuracy 95.31
# Iteration 140 | Train Loss  0.0284 | Classifier Accuracy 98.44
# Iteration 160 | Train Loss  0.0948 | Classifier Accuracy 95.31
# Iteration 180 | Train Loss  0.1816 | Classifier Accuracy 93.75
# Iteration 200 | Train Loss  0.1028 | Classifier Accuracy 93.75
# Iteration 220 | Train Loss  0.2000 | Classifier Accuracy 93.75
# Iteration 240 | Train Loss  0.0355 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 0 m 31 s
# Train Loss Mean 0.1022 | Accuracy 96.33
# Valid Loss Mean 0.0661 | Accuracy 96.78
#
#  ====================== epoch 2 ======================
# Iteration   0 | Train Loss  0.0929 | Classifier Accuracy 96.88
# Iteration  20 | Train Loss  0.0912 | Classifier Accuracy 98.44
# Iteration  40 | Train Loss  0.0367 | Classifier Accuracy 98.44
# Iteration  60 | Train Loss  0.0508 | Classifier Accuracy 98.44
# Iteration  80 | Train Loss  0.0574 | Classifier Accuracy 98.44
# Iteration 100 | Train Loss  0.0282 | Classifier Accuracy 98.44
# Iteration 120 | Train Loss  0.0182 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0532 | Classifier Accuracy 98.44
# Iteration 160 | Train Loss  0.0679 | Classifier Accuracy 98.44
# Iteration 180 | Train Loss  0.0755 | Classifier Accuracy 95.31
# Iteration 200 | Train Loss  0.0353 | Classifier Accuracy 100.00
# Iteration 220 | Train Loss  0.0396 | Classifier Accuracy 98.44
# Iteration 240 | Train Loss  0.0902 | Classifier Accuracy 93.75
#
# [Summary] Elapsed time : 0 m 38 s
# Train Loss Mean 0.0592 | Accuracy 97.85
# Valid Loss Mean 0.0971 | Accuracy 95.34
#
#  ====================== epoch 3 ======================
# Iteration   0 | Train Loss  0.1003 | Classifier Accuracy 95.31
# Iteration  20 | Train Loss  0.0274 | Classifier Accuracy 98.44
# Iteration  40 | Train Loss  0.0852 | Classifier Accuracy 98.44
# Iteration  60 | Train Loss  0.1356 | Classifier Accuracy 93.75
# Iteration  80 | Train Loss  0.0343 | Classifier Accuracy 98.44
# Iteration 100 | Train Loss  0.0594 | Classifier Accuracy 98.44
# Iteration 120 | Train Loss  0.0043 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0703 | Classifier Accuracy 98.44
# Iteration 160 | Train Loss  0.0118 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0469 | Classifier Accuracy 98.44
# Iteration 200 | Train Loss  0.1106 | Classifier Accuracy 95.31
# Iteration 220 | Train Loss  0.1349 | Classifier Accuracy 96.88
# Iteration 240 | Train Loss  0.0436 | Classifier Accuracy 98.44
#
# [Summary] Elapsed time : 0 m 38 s
# Train Loss Mean 0.0545 | Accuracy 97.98
# Valid Loss Mean 0.0690 | Accuracy 96.85
#
#  ====================== epoch 4 ======================
# Iteration   0 | Train Loss  0.0081 | Classifier Accuracy 100.00
# Iteration  20 | Train Loss  0.0328 | Classifier Accuracy 98.44
# Iteration  40 | Train Loss  0.0346 | Classifier Accuracy 98.44
# Iteration  60 | Train Loss  0.0855 | Classifier Accuracy 98.44
# Iteration  80 | Train Loss  0.0038 | Classifier Accuracy 100.00
# Iteration 100 | Train Loss  0.0059 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0125 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0697 | Classifier Accuracy 98.44
# Iteration 160 | Train Loss  0.0539 | Classifier Accuracy 96.88
# Iteration 180 | Train Loss  0.0520 | Classifier Accuracy 98.44
# Iteration 200 | Train Loss  0.0022 | Classifier Accuracy 100.00
# Iteration 220 | Train Loss  0.0335 | Classifier Accuracy 96.88
# Iteration 240 | Train Loss  0.0269 | Classifier Accuracy 98.44
#
# [Summary] Elapsed time : 0 m 38 s
# Train Loss Mean 0.0357 | Accuracy 98.69
# Valid Loss Mean 0.0798 | Accuracy 96.43
#
#  ====================== epoch 5 ======================
# Iteration   0 | Train Loss  0.0087 | Classifier Accuracy 100.00
# Iteration  20 | Train Loss  0.0019 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.1528 | Classifier Accuracy 93.75
# Iteration  60 | Train Loss  0.0032 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0193 | Classifier Accuracy 98.44
# Iteration 100 | Train Loss  0.0352 | Classifier Accuracy 98.44
# Iteration 120 | Train Loss  0.0868 | Classifier Accuracy 98.44
# Iteration 140 | Train Loss  0.1453 | Classifier Accuracy 98.44
# Iteration 160 | Train Loss  0.0280 | Classifier Accuracy 98.44
# Iteration 180 | Train Loss  0.0610 | Classifier Accuracy 96.88
# Iteration 200 | Train Loss  0.0704 | Classifier Accuracy 96.88
# Iteration 220 | Train Loss  0.0332 | Classifier Accuracy 98.44
# Iteration 240 | Train Loss  0.0257 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 0 m 38 s
# Train Loss Mean 0.0438 | Accuracy 98.36
# Valid Loss Mean 0.1984 | Accuracy 92.88
#
#  ====================== epoch 6 ======================
# Iteration   0 | Train Loss  0.0386 | Classifier Accuracy 98.44
# Iteration  20 | Train Loss  0.0180 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0097 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0039 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0309 | Classifier Accuracy 98.44
# Iteration 100 | Train Loss  0.0091 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0060 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0029 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.0053 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0043 | Classifier Accuracy 100.00
# Iteration 200 | Train Loss  0.0040 | Classifier Accuracy 100.00
# Iteration 220 | Train Loss  0.0049 | Classifier Accuracy 100.00
# Iteration 240 | Train Loss  0.0022 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 0 m 39 s
# Train Loss Mean 0.0142 | Accuracy 99.56
# Valid Loss Mean 0.0387 | Accuracy 97.87
#
#  ====================== epoch 7 ======================
# Iteration   0 | Train Loss  0.0012 | Classifier Accuracy 100.00
# Iteration  20 | Train Loss  0.0004 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0005 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0007 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0021 | Classifier Accuracy 100.00
# Iteration 100 | Train Loss  0.0027 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0032 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0034 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.0003 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0019 | Classifier Accuracy 100.00
# Iteration 200 | Train Loss  0.0018 | Classifier Accuracy 100.00
# Iteration 220 | Train Loss  0.0011 | Classifier Accuracy 100.00
# Iteration 240 | Train Loss  0.0020 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 0 m 39 s
# Train Loss Mean 0.0033 | Accuracy 99.96
# Valid Loss Mean 0.0357 | Accuracy 97.99
#
#  ====================== epoch 8 ======================
# Iteration   0 | Train Loss  0.0041 | Classifier Accuracy 100.00
# Iteration  20 | Train Loss  0.0056 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0122 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0022 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0003 | Classifier Accuracy 100.00
# Iteration 100 | Train Loss  0.0014 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0003 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0007 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.0005 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0010 | Classifier Accuracy 100.00
# Iteration 200 | Train Loss  0.0008 | Classifier Accuracy 100.00
# Iteration 220 | Train Loss  0.0012 | Classifier Accuracy 100.00
# Iteration 240 | Train Loss  0.0009 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 0 m 40 s
# Train Loss Mean 0.0018 | Accuracy 99.99
# Valid Loss Mean 0.0316 | Accuracy 98.02
#
#  ====================== epoch 9 ======================
# Iteration   0 | Train Loss  0.0010 | Classifier Accuracy 100.00
# Iteration  20 | Train Loss  0.0002 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0006 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0051 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0012 | Classifier Accuracy 100.00
# Iteration 100 | Train Loss  0.0003 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0004 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0005 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.0005 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0003 | Classifier Accuracy 100.00
# Iteration 200 | Train Loss  0.0004 | Classifier Accuracy 100.00
# Iteration 220 | Train Loss  0.0003 | Classifier Accuracy 100.00
# Iteration 240 | Train Loss  0.0002 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 0 m 39 s
# Train Loss Mean 0.0010 | Accuracy 99.99
# Valid Loss Mean 0.0322 | Accuracy 98.04
#
#  ====================== epoch 10 ======================
# Iteration   0 | Train Loss  0.0019 | Classifier Accuracy 100.00
# Iteration  20 | Train Loss  0.0011 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0008 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0005 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0003 | Classifier Accuracy 100.00
# Iteration 100 | Train Loss  0.0008 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0004 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0004 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.0003 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0026 | Classifier Accuracy 100.00
# Iteration 200 | Train Loss  0.0004 | Classifier Accuracy 100.00
# Iteration 220 | Train Loss  0.0003 | Classifier Accuracy 100.00
# Iteration 240 | Train Loss  0.0002 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 0 m 39 s
# Train Loss Mean 0.0007 | Accuracy 100.00
# Valid Loss Mean 0.0295 | Accuracy 98.12
#
#  ====================== epoch 11 ======================
# Iteration   0 | Train Loss  0.0008 | Classifier Accuracy 100.00
# Iteration  20 | Train Loss  0.0002 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0010 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0002 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0005 | Classifier Accuracy 100.00
# Iteration 100 | Train Loss  0.0021 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0002 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0005 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.0007 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0005 | Classifier Accuracy 100.00
# Iteration 200 | Train Loss  0.0004 | Classifier Accuracy 100.00
# Iteration 220 | Train Loss  0.0006 | Classifier Accuracy 100.00
# Iteration 240 | Train Loss  0.0003 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 0 m 39 s
# Train Loss Mean 0.0005 | Accuracy 100.00
# Valid Loss Mean 0.0301 | Accuracy 98.09
#
#  ====================== epoch 12 ======================
# Iteration   0 | Train Loss  0.0001 | Classifier Accuracy 100.00
# Iteration  20 | Train Loss  0.0004 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0005 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0003 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0004 | Classifier Accuracy 100.00
# Iteration 100 | Train Loss  0.0002 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0004 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0001 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.0001 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0013 | Classifier Accuracy 100.00
# Iteration 200 | Train Loss  0.0004 | Classifier Accuracy 100.00
# Iteration 220 | Train Loss  0.0001 | Classifier Accuracy 100.00
# Iteration 240 | Train Loss  0.0005 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 0 m 39 s
# Train Loss Mean 0.0006 | Accuracy 100.00
# Valid Loss Mean 0.0282 | Accuracy 98.12
#
#  ====================== epoch 13 ======================
# Iteration   0 | Train Loss  0.0003 | Classifier Accuracy 100.00
# Iteration  20 | Train Loss  0.0003 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0005 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0003 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0018 | Classifier Accuracy 100.00
# Iteration 100 | Train Loss  0.0007 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0003 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0007 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.0009 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0004 | Classifier Accuracy 100.00
# Iteration 200 | Train Loss  0.0001 | Classifier Accuracy 100.00
# Iteration 220 | Train Loss  0.0003 | Classifier Accuracy 100.00
# Iteration 240 | Train Loss  0.0002 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 0 m 39 s
# Train Loss Mean 0.0005 | Accuracy 100.00
# Valid Loss Mean 0.0302 | Accuracy 98.12
#
#  ====================== epoch 14 ======================
# Iteration   0 | Train Loss  0.0002 | Classifier Accuracy 100.00
# Iteration  20 | Train Loss  0.0011 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0001 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0001 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0004 | Classifier Accuracy 100.00
# Iteration 100 | Train Loss  0.0001 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0002 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0019 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.0005 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0019 | Classifier Accuracy 100.00
# Iteration 200 | Train Loss  0.0004 | Classifier Accuracy 100.00
# Iteration 220 | Train Loss  0.0005 | Classifier Accuracy 100.00
# Iteration 240 | Train Loss  0.0002 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 0 m 40 s
# Train Loss Mean 0.0004 | Accuracy 100.00
# Valid Loss Mean 0.0298 | Accuracy 98.16
#
#  ====================== epoch 15 ======================
# Iteration   0 | Train Loss  0.0002 | Classifier Accuracy 100.00
# Iteration  20 | Train Loss  0.0003 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0003 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0001 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0003 | Classifier Accuracy 100.00
# Iteration 100 | Train Loss  0.0003 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0004 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0002 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.0001 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0004 | Classifier Accuracy 100.00
# Iteration 200 | Train Loss  0.0002 | Classifier Accuracy 100.00
# Iteration 220 | Train Loss  0.0001 | Classifier Accuracy 100.00
# Iteration 240 | Train Loss  0.0003 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 0 m 39 s
# Train Loss Mean 0.0004 | Accuracy 100.00
# Valid Loss Mean 0.0301 | Accuracy 98.14
#
#  ====================== epoch 16 ======================
# Iteration   0 | Train Loss  0.0002 | Classifier Accuracy 100.00
# Iteration  20 | Train Loss  0.0002 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0008 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0003 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0002 | Classifier Accuracy 100.00
# Iteration 100 | Train Loss  0.0002 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0002 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0001 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.0029 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0003 | Classifier Accuracy 100.00
# Iteration 200 | Train Loss  0.0006 | Classifier Accuracy 100.00
# Iteration 220 | Train Loss  0.0015 | Classifier Accuracy 100.00
# Iteration 240 | Train Loss  0.0004 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 0 m 38 s
# Train Loss Mean 0.0006 | Accuracy 99.99
# Valid Loss Mean 0.0310 | Accuracy 98.14
#
#  ====================== epoch 17 ======================
# Iteration   0 | Train Loss  0.0001 | Classifier Accuracy 100.00
# Iteration  20 | Train Loss  0.0002 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0008 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0001 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0001 | Classifier Accuracy 100.00
# Iteration 100 | Train Loss  0.0005 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0002 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0001 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.0003 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0003 | Classifier Accuracy 100.00
# Iteration 200 | Train Loss  0.0003 | Classifier Accuracy 100.00
# Iteration 220 | Train Loss  0.0004 | Classifier Accuracy 100.00
# Iteration 240 | Train Loss  0.0004 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 0 m 38 s
# Train Loss Mean 0.0005 | Accuracy 100.00
# Valid Loss Mean 0.0285 | Accuracy 98.19
#
# EARLY STOPPING!!
# [fold: 4]
#  ====================== epoch 1 ======================
# Iteration   0 | Train Loss  2.6931 | Classifier Accuracy 0.00
# Iteration  20 | Train Loss  0.0402 | Classifier Accuracy 98.44
# Iteration  40 | Train Loss  0.0068 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0293 | Classifier Accuracy 98.44
# Iteration  80 | Train Loss  0.0481 | Classifier Accuracy 96.88
# Iteration 100 | Train Loss  0.0199 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0092 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0839 | Classifier Accuracy 98.44
# Iteration 160 | Train Loss  0.0478 | Classifier Accuracy 96.88
# Iteration 180 | Train Loss  0.0304 | Classifier Accuracy 100.00
# Iteration 200 | Train Loss  0.0875 | Classifier Accuracy 96.88
# Iteration 220 | Train Loss  0.0721 | Classifier Accuracy 95.31
# Iteration 240 | Train Loss  0.1061 | Classifier Accuracy 98.44
#
# [Summary] Elapsed time : 0 m 32 s
# Train Loss Mean 0.0748 | Accuracy 97.64
# Valid Loss Mean 0.0326 | Accuracy 97.87
#
#  ====================== epoch 2 ======================
# Iteration   0 | Train Loss  0.0118 | Classifier Accuracy 100.00
# Iteration  20 | Train Loss  0.0050 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0199 | Classifier Accuracy 98.44
# Iteration  60 | Train Loss  0.0811 | Classifier Accuracy 98.44
# Iteration  80 | Train Loss  0.0320 | Classifier Accuracy 98.44
# Iteration 100 | Train Loss  0.0067 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0484 | Classifier Accuracy 98.44
# Iteration 140 | Train Loss  0.0018 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.0258 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.1060 | Classifier Accuracy 95.31
# Iteration 200 | Train Loss  0.0840 | Classifier Accuracy 95.31
# Iteration 220 | Train Loss  0.0512 | Classifier Accuracy 98.44
# Iteration 240 | Train Loss  0.0144 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 0 m 39 s
# Train Loss Mean 0.0400 | Accuracy 98.46
# Valid Loss Mean 0.0588 | Accuracy 96.88
#
#  ====================== epoch 3 ======================
# Iteration   0 | Train Loss  0.0391 | Classifier Accuracy 98.44
# Iteration  20 | Train Loss  0.0284 | Classifier Accuracy 98.44
# Iteration  40 | Train Loss  0.0015 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0097 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0702 | Classifier Accuracy 95.31
# Iteration 100 | Train Loss  0.0563 | Classifier Accuracy 98.44
# Iteration 120 | Train Loss  0.0256 | Classifier Accuracy 98.44
# Iteration 140 | Train Loss  0.0074 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.0687 | Classifier Accuracy 96.88
# Iteration 180 | Train Loss  0.0158 | Classifier Accuracy 100.00
# Iteration 200 | Train Loss  0.0262 | Classifier Accuracy 98.44
# Iteration 220 | Train Loss  0.0398 | Classifier Accuracy 98.44
# Iteration 240 | Train Loss  0.0527 | Classifier Accuracy 96.88
#
# [Summary] Elapsed time : 0 m 39 s
# Train Loss Mean 0.0361 | Accuracy 98.66
# Valid Loss Mean 0.0437 | Accuracy 97.42
#
#  ====================== epoch 4 ======================
# Iteration   0 | Train Loss  0.0354 | Classifier Accuracy 98.44
# Iteration  20 | Train Loss  0.0132 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0103 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0074 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0417 | Classifier Accuracy 98.44
# Iteration 100 | Train Loss  0.0002 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0077 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0141 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.0476 | Classifier Accuracy 96.88
# Iteration 180 | Train Loss  0.0094 | Classifier Accuracy 100.00
# Iteration 200 | Train Loss  0.0860 | Classifier Accuracy 95.31
# Iteration 220 | Train Loss  0.0300 | Classifier Accuracy 98.44
# Iteration 240 | Train Loss  0.0388 | Classifier Accuracy 98.44
#
# [Summary] Elapsed time : 0 m 39 s
# Train Loss Mean 0.0258 | Accuracy 99.08
# Valid Loss Mean 0.0751 | Accuracy 96.53
#
#  ====================== epoch 5 ======================
# Iteration   0 | Train Loss  0.0957 | Classifier Accuracy 98.44
# Iteration  20 | Train Loss  0.0932 | Classifier Accuracy 96.88
# Iteration  40 | Train Loss  0.0700 | Classifier Accuracy 93.75
# Iteration  60 | Train Loss  0.0302 | Classifier Accuracy 98.44
# Iteration  80 | Train Loss  0.0132 | Classifier Accuracy 100.00
# Iteration 100 | Train Loss  0.1675 | Classifier Accuracy 96.88
# Iteration 120 | Train Loss  0.0046 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0540 | Classifier Accuracy 95.31
# Iteration 160 | Train Loss  0.0255 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0188 | Classifier Accuracy 98.44
# Iteration 200 | Train Loss  0.0115 | Classifier Accuracy 100.00
# Iteration 220 | Train Loss  0.0888 | Classifier Accuracy 96.88
# Iteration 240 | Train Loss  0.0188 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 0 m 39 s
# Train Loss Mean 0.0392 | Accuracy 98.66
# Valid Loss Mean 0.0670 | Accuracy 96.95
#
#  ====================== epoch 6 ======================
# Iteration   0 | Train Loss  0.0786 | Classifier Accuracy 96.88
# Iteration  20 | Train Loss  0.0202 | Classifier Accuracy 98.44
# Iteration  40 | Train Loss  0.0030 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0088 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0225 | Classifier Accuracy 98.44
# Iteration 100 | Train Loss  0.0081 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0023 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0048 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.0012 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0114 | Classifier Accuracy 100.00
# Iteration 200 | Train Loss  0.0022 | Classifier Accuracy 100.00
# Iteration 220 | Train Loss  0.1035 | Classifier Accuracy 95.31
# Iteration 240 | Train Loss  0.0014 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 0 m 39 s
# Train Loss Mean 0.0129 | Accuracy 99.60
# Valid Loss Mean 0.0205 | Accuracy 98.34
#
#  ====================== epoch 7 ======================
# Iteration   0 | Train Loss  0.0007 | Classifier Accuracy 100.00
# Iteration  20 | Train Loss  0.0021 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0025 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0016 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0005 | Classifier Accuracy 100.00
# Iteration 100 | Train Loss  0.0039 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0025 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0027 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.0007 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0009 | Classifier Accuracy 100.00
# Iteration 200 | Train Loss  0.0017 | Classifier Accuracy 100.00
# Iteration 220 | Train Loss  0.0003 | Classifier Accuracy 100.00
# Iteration 240 | Train Loss  0.0006 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 0 m 39 s
# Train Loss Mean 0.0027 | Accuracy 99.96
# Valid Loss Mean 0.0140 | Accuracy 98.66
#
#  ====================== epoch 8 ======================
# Iteration   0 | Train Loss  0.0040 | Classifier Accuracy 100.00
# Iteration  20 | Train Loss  0.0037 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0008 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0003 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0008 | Classifier Accuracy 100.00
# ...
# Iteration  20 | Train Loss  0.0019 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0113 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0157 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0100 | Classifier Accuracy 100.00
# Iteration 100 | Train Loss  0.0127 | Classifier Accuracy 98.44
# Iteration 120 | Train Loss  0.0106 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0059 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.0061 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0768 | Classifier Accuracy 96.88
# Iteration 200 | Train Loss  0.0020 | Classifier Accuracy 100.00
# Iteration 220 | Train Loss  0.0170 | Classifier Accuracy 98.44
# Iteration 240 | Train Loss  0.0056 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 0 m 41 s
# Train Loss Mean 0.0183 | Accuracy 99.34
# Valid Loss Mean 0.0619 | Accuracy 96.92
#
#  ====================== epoch 6 ======================
# Iteration   0 | Train Loss  0.0046 | Classifier Accuracy 100.00
# Iteration  20 | Train Loss  0.0088 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0115 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0015 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0012 | Classifier Accuracy 100.00
# Iteration 100 | Train Loss  0.0060 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0133 | Classifier Accuracy 98.44
# Iteration 140 | Train Loss  0.0044 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.0028 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0003 | Classifier Accuracy 100.00
# Iteration 200 | Train Loss  0.0013 | Classifier Accuracy 100.00
# Iteration 220 | Train Loss  0.0144 | Classifier Accuracy 98.44
# Iteration 240 | Train Loss  0.0006 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 0 m 41 s
# Train Loss Mean 0.0085 | Accuracy 99.74
# Valid Loss Mean 0.0139 | Accuracy 98.64
#
#  ====================== epoch 7 ======================
# Iteration   0 | Train Loss  0.0001 | Classifier Accuracy 100.00
# Iteration  20 | Train Loss  0.0003 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0008 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0043 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0002 | Classifier Accuracy 100.00
# Iteration 100 | Train Loss  0.0011 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0007 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0008 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.0004 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0053 | Classifier Accuracy 100.00
# Iteration 200 | Train Loss  0.0011 | Classifier Accuracy 100.00
# Iteration 220 | Train Loss  0.0006 | Classifier Accuracy 100.00
# Iteration 240 | Train Loss  0.0002 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 0 m 41 s
# Train Loss Mean 0.0015 | Accuracy 99.99
# Valid Loss Mean 0.0119 | Accuracy 98.69
#
#  ====================== epoch 8 ======================
# Iteration   0 | Train Loss  0.0004 | Classifier Accuracy 100.00
# Iteration  20 | Train Loss  0.0006 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0016 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0005 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0003 | Classifier Accuracy 100.00
# Iteration 100 | Train Loss  0.0006 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0010 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0005 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.0004 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0011 | Classifier Accuracy 100.00
# Iteration 200 | Train Loss  0.0011 | Classifier Accuracy 100.00
# Iteration 220 | Train Loss  0.0004 | Classifier Accuracy 100.00
# Iteration 240 | Train Loss  0.0021 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 0 m 41 s
# Train Loss Mean 0.0008 | Accuracy 100.00
# Valid Loss Mean 0.0115 | Accuracy 98.71
#
#  ====================== epoch 9 ======================
# Iteration   0 | Train Loss  0.0009 | Classifier Accuracy 100.00
# Iteration  20 | Train Loss  0.0001 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0001 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0014 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0004 | Classifier Accuracy 100.00
# Iteration 100 | Train Loss  0.0002 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0015 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0001 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.0001 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0002 | Classifier Accuracy 100.00
# Iteration 200 | Train Loss  0.0011 | Classifier Accuracy 100.00
# Iteration 220 | Train Loss  0.0002 | Classifier Accuracy 100.00
# Iteration 240 | Train Loss  0.0001 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 0 m 41 s
# Train Loss Mean 0.0005 | Accuracy 100.00
# Valid Loss Mean 0.0097 | Accuracy 98.78
#
#  ====================== epoch 10 ======================
# Iteration   0 | Train Loss  0.0006 | Classifier Accuracy 100.00
# Iteration  20 | Train Loss  0.0009 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0002 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0004 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0002 | Classifier Accuracy 100.00
# Iteration 100 | Train Loss  0.0002 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0001 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0002 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.0002 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0005 | Classifier Accuracy 100.00
# Iteration 200 | Train Loss  0.0001 | Classifier Accuracy 100.00
# Iteration 220 | Train Loss  0.0002 | Classifier Accuracy 100.00
# Iteration 240 | Train Loss  0.0005 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 0 m 41 s
# Train Loss Mean 0.0004 | Accuracy 100.00
# Valid Loss Mean 0.0096 | Accuracy 98.76
#
#  ====================== epoch 11 ======================
# Iteration   0 | Train Loss  0.0001 | Classifier Accuracy 100.00
# Iteration  20 | Train Loss  0.0001 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0003 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0004 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0001 | Classifier Accuracy 100.00
# Iteration 100 | Train Loss  0.0002 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0001 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0001 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.0001 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0001 | Classifier Accuracy 100.00
# Iteration 200 | Train Loss  0.0011 | Classifier Accuracy 100.00
# Iteration 220 | Train Loss  0.0006 | Classifier Accuracy 100.00
# Iteration 240 | Train Loss  0.0001 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 0 m 41 s
# Train Loss Mean 0.0004 | Accuracy 100.00
# Valid Loss Mean 0.0094 | Accuracy 98.81
#
#  ====================== epoch 12 ======================
# Iteration   0 | Train Loss  0.0002 | Classifier Accuracy 100.00
# Iteration  20 | Train Loss  0.0003 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0003 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0002 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0003 | Classifier Accuracy 100.00
# Iteration 100 | Train Loss  0.0006 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0009 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0002 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.0008 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0001 | Classifier Accuracy 100.00
# Iteration 200 | Train Loss  0.0001 | Classifier Accuracy 100.00
# Iteration 220 | Train Loss  0.0001 | Classifier Accuracy 100.00
# Iteration 240 | Train Loss  0.0002 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 0 m 41 s
# Train Loss Mean 0.0004 | Accuracy 100.00
# Valid Loss Mean 0.0094 | Accuracy 98.76
#
#  ====================== epoch 13 ======================
# Iteration   0 | Train Loss  0.0003 | Classifier Accuracy 100.00
# Iteration  20 | Train Loss  0.0001 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0003 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0001 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0002 | Classifier Accuracy 100.00
# Iteration 100 | Train Loss  0.0006 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0002 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0012 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.0001 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0003 | Classifier Accuracy 100.00
# Iteration 200 | Train Loss  0.0003 | Classifier Accuracy 100.00
# Iteration 220 | Train Loss  0.0002 | Classifier Accuracy 100.00
# Iteration 240 | Train Loss  0.0001 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 0 m 41 s
# Train Loss Mean 0.0003 | Accuracy 100.00
# Valid Loss Mean 0.0095 | Accuracy 98.76
#
#  ====================== epoch 14 ======================
# Iteration   0 | Train Loss  0.0000 | Classifier Accuracy 100.00
# Iteration  20 | Train Loss  0.0003 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0003 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0001 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0001 | Classifier Accuracy 100.00
# Iteration 100 | Train Loss  0.0002 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0001 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0030 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.0001 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0001 | Classifier Accuracy 100.00
# Iteration 200 | Train Loss  0.0001 | Classifier Accuracy 100.00
# Iteration 220 | Train Loss  0.0002 | Classifier Accuracy 100.00
# Iteration 240 | Train Loss  0.0001 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 0 m 41 s
# Train Loss Mean 0.0003 | Accuracy 100.00
# Valid Loss Mean 0.0096 | Accuracy 98.76
#
#  ====================== epoch 15 ======================
# Iteration   0 | Train Loss  0.0007 | Classifier Accuracy 100.00
# Iteration  20 | Train Loss  0.0019 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0001 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0004 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0006 | Classifier Accuracy 100.00
# Iteration 100 | Train Loss  0.0003 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0003 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0002 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.0000 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0006 | Classifier Accuracy 100.00
# Iteration 200 | Train Loss  0.0001 | Classifier Accuracy 100.00
# Iteration 220 | Train Loss  0.0023 | Classifier Accuracy 100.00
# Iteration 240 | Train Loss  0.0001 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 0 m 42 s
# Train Loss Mean 0.0003 | Accuracy 100.00
# Valid Loss Mean 0.0092 | Accuracy 98.74
#
#  ====================== epoch 16 ======================
# Iteration   0 | Train Loss  0.0001 | Classifier Accuracy 100.00
# Iteration  20 | Train Loss  0.0003 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0012 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0001 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0004 | Classifier Accuracy 100.00
# Iteration 100 | Train Loss  0.0006 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0001 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0004 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.0005 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0001 | Classifier Accuracy 100.00
# Iteration 200 | Train Loss  0.0001 | Classifier Accuracy 100.00
# Iteration 220 | Train Loss  0.0002 | Classifier Accuracy 100.00
# Iteration 240 | Train Loss  0.0003 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 0 m 42 s
# Train Loss Mean 0.0003 | Accuracy 100.00
# Valid Loss Mean 0.0093 | Accuracy 98.83
#
#  ====================== epoch 17 ======================
# Iteration   0 | Train Loss  0.0001 | Classifier Accuracy 100.00
# Iteration  20 | Train Loss  0.0001 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0005 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0001 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0003 | Classifier Accuracy 100.00
# Iteration 100 | Train Loss  0.0011 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0001 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0001 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.0000 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0001 | Classifier Accuracy 100.00
# Iteration 200 | Train Loss  0.0023 | Classifier Accuracy 100.00
# Iteration 220 | Train Loss  0.0002 | Classifier Accuracy 100.00
# Iteration 240 | Train Loss  0.0002 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 0 m 42 s
# Train Loss Mean 0.0003 | Accuracy 100.00
# Valid Loss Mean 0.0095 | Accuracy 98.76
#
#  ====================== epoch 18 ======================
# Iteration   0 | Train Loss  0.0002 | Classifier Accuracy 100.00
# Iteration  20 | Train Loss  0.0004 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0003 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0003 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0021 | Classifier Accuracy 100.00
# Iteration 100 | Train Loss  0.0001 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0000 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0001 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.0001 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0003 | Classifier Accuracy 100.00
# Iteration 200 | Train Loss  0.0001 | Classifier Accuracy 100.00
# Iteration 220 | Train Loss  0.0001 | Classifier Accuracy 100.00
# Iteration 240 | Train Loss  0.0002 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 0 m 41 s
# Train Loss Mean 0.0003 | Accuracy 100.00
# Valid Loss Mean 0.0093 | Accuracy 98.74
#
#  ====================== epoch 19 ======================
# Iteration   0 | Train Loss  0.0005 | Classifier Accuracy 100.00
# Iteration  20 | Train Loss  0.0001 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0001 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0001 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0000 | Classifier Accuracy 100.00
# Iteration 100 | Train Loss  0.0002 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0003 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0004 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.0002 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0058 | Classifier Accuracy 100.00
# Iteration 200 | Train Loss  0.0001 | Classifier Accuracy 100.00
# Iteration 220 | Train Loss  0.0004 | Classifier Accuracy 100.00
# Iteration 240 | Train Loss  0.0003 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 0 m 41 s
# Train Loss Mean 0.0003 | Accuracy 100.00
# Valid Loss Mean 0.0099 | Accuracy 98.74
#
#  ====================== epoch 20 ======================
# Iteration   0 | Train Loss  0.0009 | Classifier Accuracy 100.00
# Iteration  20 | Train Loss  0.0005 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0001 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0002 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0001 | Classifier Accuracy 100.00
# Iteration 100 | Train Loss  0.0001 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0006 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0001 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.0001 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0003 | Classifier Accuracy 100.00
# Iteration 200 | Train Loss  0.0003 | Classifier Accuracy 100.00
# Iteration 220 | Train Loss  0.0001 | Classifier Accuracy 100.00
# Iteration 240 | Train Loss  0.0007 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 0 m 41 s
# Train Loss Mean 0.0003 | Accuracy 100.00
# Valid Loss Mean 0.0094 | Accuracy 98.78
#
# EARLY STOPPING!!

# %% [markdown]
# # EfficientNet B7

# %%
class efficientnet(torch.nn.Module):
  def __init__(self):
    super(efficientnet, self).__init__()
    self.conv2d = nn.Conv2d(3, 3, 3, stride=1)
    self.effnet = EfficientNet.from_name('efficientnet-b7',dropout_rate=0.2) 
    self.FC = nn.Linear(1000,2)

    nn.init.xavier_normal_(self.FC.weight)

  def forward(self, x):
    x = F.silu(self.conv2d(x))

    #effnet추가
    x = F.silu(self.effnet(x))
    
    x = self.FC(x)
    return x

model = efficientnet()

# %%
#optimizer 설정
import torch_optimizer as optim
model.to(device)
optimizer = optim.RAdam(model.parameters(), lr=0.0015, betas=(0.9,0.999), weight_decay=0)
lr_sched = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=50)

# %%
#모델 훈련
num_epochs = 40
EARLY_STOPPING_EPOCH = 7
SEED = 42

# cross validation을 적용하기 위한 KFold 생성
from sklearn.model_selection import KFold
kfold = KFold(n_splits=4, shuffle=True, random_state=SEED) #4-fold

effi_models=[] #각 fold의 best model을 담을 리스트 

#train_df에서 train_index와 valid_index 생성
for fold_index, (train_index, valid_index) in enumerate(kfold.split(train_df),1): #enumerate(,1) 1부터 index시작
  print('[fold: %d' %fold_index)

  #CUDA cahe 초기화
  torch.cuda.empty_cache()

  #train fold, valid fold 분할
  train = train_df.iloc[train_index]
  valid = train_df.iloc[valid_index]

  tr_dataset = FaceDataset(image_label=train, transforms=transforms_tr)
  val_dataset = FaceDataset(image_label=valid, transforms=transforms_val)

  train_loader = DataLoader(tr_dataset, batch_size=64, shuffle=True, num_workers=8)
  valid_loader = DataLoader(val_dataset, batch_size=64, shuffle=True, num_workers=8)

  #train 시작
  valid_early_stop = 0

  valid_best_loss = float('inf')
  since = time.time()

  final_train_loss = []
  final_train_acc = []
  final_valid_loss = []
  final_valid_acc = []

  for e in range(num_epochs) :
    print(f' ====================== epoch %d ======================' % (e+1) )
    train_loss_list = []
    train_acc_list = []

    # train
    model.train()
    for i, (images, targets) in enumerate(train_loader) : 
      optimizer.zero_grad()
      
      images = images.to(device, dtype)
      targets = targets.to(device, ltype)
    
      scores = model(images)
      _, preds = scores.max(dim=1)

      loss = F.cross_entropy(scores, targets)
      loss.backward()
      optimizer.step()
      
      correct = sum(targets == preds).cpu()
      acc=(correct/64 * 100)

      train_loss_list.append(loss)
      train_acc_list.append(acc)

      if i % 20 == 0 :
        print(f'Iteration %3.d | Train Loss  %.4f | Classifier Accuracy %2.2f' % (i, loss, acc))

    train_mean_loss = np.mean(train_loss_list, dtype="float64")
    train_mean_acc = np.mean(train_acc_list, dtype="float64")

    final_train_loss.append(train_mean_loss)
    final_train_acc.append(train_mean_acc)
    
    epoch_time = time.time() - since
    since = time.time()

    print('')
    print(f'[Summary] Elapsed time : %.0f m %.0f s' % (epoch_time // 60, epoch_time % 60))
    print(f'Train Loss Mean %.4f | Accuracy %2.2f ' % (train_mean_loss, train_mean_acc) )

    # validation 
    model.eval()
    valid_loss_list = []
    valid_acc_list = []
    for i, (images, targets) in enumerate(valid_loader) : 
      optimizer.zero_grad()
      images = images.to(device=device, dtype=dtype)
      targets = targets.to(device=device, dtype=ltype)

      with torch.no_grad():
        scores = model(images)
        loss = torch.nn.functional.cross_entropy(scores, targets)
        _, preds = scores.max(dim=1)
      
      correct = sum(targets == preds).cpu()
      acc=(correct/64 * 100)

      valid_loss_list.append(loss)
      valid_acc_list.append(acc)
  
    val_mean_loss = np.mean(valid_loss_list, dtype="float64")
    val_mean_acc = np.mean(valid_acc_list, dtype="float64")

    final_valid_loss.append(val_mean_loss)
    final_valid_acc.append(val_mean_acc)

    print(f'Valid Loss Mean %.4f | Accuracy %2.2f ' % (val_mean_loss, val_mean_acc) )
    print('')

    if val_mean_loss < valid_best_loss:
      valid_best_loss = val_mean_loss
      valid_early_stop = 0
      best_model = model
      if (e+1) == num_epochs:
        effi_models.append(best_model)
        
    else:
      # early stopping    
      valid_early_stop += 1
      if valid_early_stop >= EARLY_STOPPING_EPOCH:
        print("EARLY STOPPING!!")
        effi_models.append(best_model)
        break

    lr_sched.step()
# Out:
# [fold: 1
#  ====================== epoch 1 ======================
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Iteration   0 | Train Loss  0.7392 | Classifier Accuracy 43.75
# Iteration  20 | Train Loss  0.7423 | Classifier Accuracy 50.00
# Iteration  40 | Train Loss  0.7831 | Classifier Accuracy 50.00
# Iteration  60 | Train Loss  0.6495 | Classifier Accuracy 56.25
# Iteration  80 | Train Loss  0.6801 | Classifier Accuracy 56.25
# Iteration 100 | Train Loss  0.7611 | Classifier Accuracy 53.12
# Iteration 120 | Train Loss  0.7058 | Classifier Accuracy 53.12
# Iteration 140 | Train Loss  0.6762 | Classifier Accuracy 62.50
# Iteration 160 | Train Loss  0.7137 | Classifier Accuracy 60.94
# Iteration 180 | Train Loss  0.7609 | Classifier Accuracy 48.44
# Iteration 200 | Train Loss  0.6428 | Classifier Accuracy 51.56
# Iteration 220 | Train Loss  0.6774 | Classifier Accuracy 54.69
#
# [Summary] Elapsed time : 1 m 36 s
# Train Loss Mean 0.7347 | Accuracy 52.22
# Valid Loss Mean 0.7142 | Accuracy 49.74
#
#  ====================== epoch 2 ======================
# Iteration   0 | Train Loss  0.7256 | Classifier Accuracy 51.56
# Iteration  20 | Train Loss  0.7083 | Classifier Accuracy 48.44
# Iteration  40 | Train Loss  0.6536 | Classifier Accuracy 54.69
# Iteration  60 | Train Loss  0.6982 | Classifier Accuracy 42.19
# Iteration  80 | Train Loss  0.7074 | Classifier Accuracy 59.38
# Iteration 100 | Train Loss  0.6535 | Classifier Accuracy 65.62
# Iteration 120 | Train Loss  0.7454 | Classifier Accuracy 57.81
# Iteration 140 | Train Loss  0.5851 | Classifier Accuracy 68.75
# Iteration 160 | Train Loss  0.6382 | Classifier Accuracy 70.31
# Iteration 180 | Train Loss  0.6823 | Classifier Accuracy 57.81
# Iteration 200 | Train Loss  0.6029 | Classifier Accuracy 70.31
# Iteration 220 | Train Loss  0.6242 | Classifier Accuracy 67.19
#
# [Summary] Elapsed time : 1 m 47 s
# Train Loss Mean 0.6622 | Accuracy 60.56
# Valid Loss Mean 0.7160 | Accuracy 49.15
#
#  ====================== epoch 3 ======================
# Iteration   0 | Train Loss  0.5782 | Classifier Accuracy 76.56
# Iteration  20 | Train Loss  0.4693 | Classifier Accuracy 79.69
# Iteration  40 | Train Loss  0.4966 | Classifier Accuracy 76.56
# Iteration  60 | Train Loss  0.5789 | Classifier Accuracy 75.00
# Iteration  80 | Train Loss  0.5596 | Classifier Accuracy 75.00
# Iteration 100 | Train Loss  0.4609 | Classifier Accuracy 84.38
# Iteration 120 | Train Loss  0.5734 | Classifier Accuracy 76.56
# Iteration 140 | Train Loss  0.5100 | Classifier Accuracy 76.56
# Iteration 160 | Train Loss  0.5180 | Classifier Accuracy 76.56
# Iteration 180 | Train Loss  0.5420 | Classifier Accuracy 73.44
# Iteration 200 | Train Loss  0.5995 | Classifier Accuracy 71.88
# Iteration 220 | Train Loss  0.4632 | Classifier Accuracy 79.69
#
# [Summary] Elapsed time : 1 m 46 s
# Train Loss Mean 0.5320 | Accuracy 74.26
# Valid Loss Mean 0.5235 | Accuracy 74.74
#
#  ====================== epoch 4 ======================
# Iteration   0 | Train Loss  0.4148 | Classifier Accuracy 79.69
# Iteration  20 | Train Loss  0.5529 | Classifier Accuracy 75.00
# Iteration  40 | Train Loss  0.2788 | Classifier Accuracy 89.06
# Iteration  60 | Train Loss  0.4019 | Classifier Accuracy 79.69
# Iteration  80 | Train Loss  0.4045 | Classifier Accuracy 81.25
# Iteration 100 | Train Loss  0.3977 | Classifier Accuracy 85.94
# Iteration 120 | Train Loss  0.3911 | Classifier Accuracy 79.69
# Iteration 140 | Train Loss  0.3942 | Classifier Accuracy 79.69
# Iteration 160 | Train Loss  0.3788 | Classifier Accuracy 84.38
# Iteration 180 | Train Loss  0.3903 | Classifier Accuracy 82.81
# Iteration 200 | Train Loss  0.3338 | Classifier Accuracy 85.94
# Iteration 220 | Train Loss  0.3644 | Classifier Accuracy 82.81
#
# [Summary] Elapsed time : 1 m 46 s
# Train Loss Mean 0.4038 | Accuracy 81.58
# Valid Loss Mean 0.4693 | Accuracy 78.68
#
#  ====================== epoch 5 ======================
# Iteration   0 | Train Loss  0.2890 | Classifier Accuracy 90.62
# Iteration  20 | Train Loss  0.3169 | Classifier Accuracy 87.50
# Iteration  40 | Train Loss  0.3372 | Classifier Accuracy 84.38
# Iteration  60 | Train Loss  0.2581 | Classifier Accuracy 85.94
# Iteration  80 | Train Loss  0.3761 | Classifier Accuracy 81.25
# Iteration 100 | Train Loss  0.4096 | Classifier Accuracy 78.12
# Iteration 120 | Train Loss  0.3306 | Classifier Accuracy 84.38
# Iteration 140 | Train Loss  0.3709 | Classifier Accuracy 81.25
# Iteration 160 | Train Loss  0.3552 | Classifier Accuracy 78.12
# Iteration 180 | Train Loss  0.4163 | Classifier Accuracy 79.69
# Iteration 200 | Train Loss  0.2800 | Classifier Accuracy 89.06
# Iteration 220 | Train Loss  0.3488 | Classifier Accuracy 84.38
#
# [Summary] Elapsed time : 1 m 46 s
# Train Loss Mean 0.3272 | Accuracy 85.64
# Valid Loss Mean 0.7248 | Accuracy 60.94
#
#  ====================== epoch 6 ======================
# Iteration   0 | Train Loss  0.3464 | Classifier Accuracy 84.38
# Iteration  20 | Train Loss  0.3457 | Classifier Accuracy 82.81
# Iteration  40 | Train Loss  0.2502 | Classifier Accuracy 87.50
# Iteration  60 | Train Loss  0.2618 | Classifier Accuracy 87.50
# Iteration  80 | Train Loss  0.3439 | Classifier Accuracy 85.94
# Iteration 100 | Train Loss  0.3951 | Classifier Accuracy 81.25
# Iteration 120 | Train Loss  0.3277 | Classifier Accuracy 82.81
# Iteration 140 | Train Loss  0.2745 | Classifier Accuracy 87.50
# Iteration 160 | Train Loss  0.2421 | Classifier Accuracy 89.06
# Iteration 180 | Train Loss  0.2625 | Classifier Accuracy 93.75
# Iteration 200 | Train Loss  0.3278 | Classifier Accuracy 87.50
# Iteration 220 | Train Loss  0.3782 | Classifier Accuracy 84.38
#
# [Summary] Elapsed time : 1 m 46 s
# Train Loss Mean 0.3205 | Accuracy 86.23
# Valid Loss Mean 0.4306 | Accuracy 82.59
#
#  ====================== epoch 7 ======================
# Iteration   0 | Train Loss  0.1966 | Classifier Accuracy 89.06
# Iteration  20 | Train Loss  0.2707 | Classifier Accuracy 89.06
# Iteration  40 | Train Loss  0.2047 | Classifier Accuracy 89.06
# Iteration  60 | Train Loss  0.3496 | Classifier Accuracy 87.50
# Iteration  80 | Train Loss  0.3577 | Classifier Accuracy 85.94
# Iteration 100 | Train Loss  0.2273 | Classifier Accuracy 92.19
# Iteration 120 | Train Loss  0.3593 | Classifier Accuracy 82.81
# Iteration 140 | Train Loss  0.2828 | Classifier Accuracy 84.38
# Iteration 160 | Train Loss  0.1663 | Classifier Accuracy 95.31
# Iteration 180 | Train Loss  0.2767 | Classifier Accuracy 90.62
# Iteration 200 | Train Loss  0.2427 | Classifier Accuracy 93.75
# Iteration 220 | Train Loss  0.2619 | Classifier Accuracy 87.50
#
# [Summary] Elapsed time : 1 m 46 s
# Train Loss Mean 0.2804 | Accuracy 88.16
# Valid Loss Mean 0.4054 | Accuracy 81.86
#
#  ====================== epoch 8 ======================
# Iteration   0 | Train Loss  0.1808 | Classifier Accuracy 93.75
# Iteration  20 | Train Loss  0.1645 | Classifier Accuracy 93.75
# Iteration  40 | Train Loss  0.1645 | Classifier Accuracy 95.31
# Iteration  60 | Train Loss  0.0953 | Classifier Accuracy 96.88
# Iteration  80 | Train Loss  0.2716 | Classifier Accuracy 87.50
# Iteration 100 | Train Loss  0.2586 | Classifier Accuracy 89.06
# Iteration 120 | Train Loss  0.2439 | Classifier Accuracy 89.06
# Iteration 140 | Train Loss  0.1259 | Classifier Accuracy 93.75
# Iteration 160 | Train Loss  0.1906 | Classifier Accuracy 92.19
# Iteration 180 | Train Loss  0.1721 | Classifier Accuracy 93.75
# Iteration 200 | Train Loss  0.1037 | Classifier Accuracy 95.31
# Iteration 220 | Train Loss  0.2720 | Classifier Accuracy 89.06
#
# [Summary] Elapsed time : 1 m 46 s
# Train Loss Mean 0.1757 | Accuracy 93.09
# Valid Loss Mean 0.3533 | Accuracy 84.69
#
#  ====================== epoch 9 ======================
# Iteration   0 | Train Loss  0.1807 | Classifier Accuracy 95.31
# Iteration  20 | Train Loss  0.0802 | Classifier Accuracy 95.31
# Iteration  40 | Train Loss  0.1213 | Classifier Accuracy 96.88
# Iteration  60 | Train Loss  0.1591 | Classifier Accuracy 95.31
# Iteration  80 | Train Loss  0.1147 | Classifier Accuracy 95.31
# Iteration 100 | Train Loss  0.1802 | Classifier Accuracy 92.19
# Iteration 120 | Train Loss  0.1448 | Classifier Accuracy 95.31
# Iteration 140 | Train Loss  0.1945 | Classifier Accuracy 92.19
# Iteration 160 | Train Loss  0.1439 | Classifier Accuracy 96.88
# Iteration 180 | Train Loss  0.0949 | Classifier Accuracy 96.88
# Iteration 200 | Train Loss  0.1190 | Classifier Accuracy 93.75
# Iteration 220 | Train Loss  0.1096 | Classifier Accuracy 95.31
#
# [Summary] Elapsed time : 1 m 46 s
# Train Loss Mean 0.1331 | Accuracy 94.89
# Valid Loss Mean 0.4415 | Accuracy 82.54
#
#  ====================== epoch 10 ======================
# Iteration   0 | Train Loss  0.0925 | Classifier Accuracy 95.31
# Iteration  20 | Train Loss  0.1829 | Classifier Accuracy 92.19
# Iteration  40 | Train Loss  0.0739 | Classifier Accuracy 95.31
# Iteration  60 | Train Loss  0.2222 | Classifier Accuracy 92.19
# Iteration  80 | Train Loss  0.1244 | Classifier Accuracy 96.88
# Iteration 100 | Train Loss  0.1017 | Classifier Accuracy 96.88
# Iteration 120 | Train Loss  0.1312 | Classifier Accuracy 95.31
# Iteration 140 | Train Loss  0.1475 | Classifier Accuracy 92.19
# Iteration 160 | Train Loss  0.1637 | Classifier Accuracy 90.62
# Iteration 180 | Train Loss  0.1275 | Classifier Accuracy 95.31
# Iteration 200 | Train Loss  0.1158 | Classifier Accuracy 96.88
# Iteration 220 | Train Loss  0.2934 | Classifier Accuracy 90.62
#
# [Summary] Elapsed time : 1 m 46 s
# Train Loss Mean 0.1213 | Accuracy 95.05
# Valid Loss Mean 0.4610 | Accuracy 84.93
#
#  ====================== epoch 11 ======================
# Iteration   0 | Train Loss  0.0276 | Classifier Accuracy 100.00
# Iteration  20 | Train Loss  0.0487 | Classifier Accuracy 98.44
# Iteration  40 | Train Loss  0.0981 | Classifier Accuracy 95.31
# Iteration  60 | Train Loss  0.0758 | Classifier Accuracy 96.88
# Iteration  80 | Train Loss  0.0947 | Classifier Accuracy 98.44
# Iteration 100 | Train Loss  0.0597 | Classifier Accuracy 98.44
# Iteration 120 | Train Loss  0.0352 | Classifier Accuracy 98.44
# Iteration 140 | Train Loss  0.0966 | Classifier Accuracy 96.88
# Iteration 160 | Train Loss  0.0685 | Classifier Accuracy 98.44
# Iteration 180 | Train Loss  0.0536 | Classifier Accuracy 98.44
# Iteration 200 | Train Loss  0.1256 | Classifier Accuracy 96.88
# Iteration 220 | Train Loss  0.1151 | Classifier Accuracy 92.19
#
# [Summary] Elapsed time : 1 m 46 s
# Train Loss Mean 0.1098 | Accuracy 95.64
# Valid Loss Mean 0.3978 | Accuracy 85.58
#
#  ====================== epoch 12 ======================
# Iteration   0 | Train Loss  0.0879 | Classifier Accuracy 95.31
# Iteration  20 | Train Loss  0.0280 | Classifier Accuracy 98.44
# Iteration  40 | Train Loss  0.0411 | Classifier Accuracy 98.44
# Iteration  60 | Train Loss  0.1203 | Classifier Accuracy 95.31
# Iteration  80 | Train Loss  0.0521 | Classifier Accuracy 98.44
# Iteration 100 | Train Loss  0.1308 | Classifier Accuracy 98.44
# Iteration 120 | Train Loss  0.1417 | Classifier Accuracy 90.62
# Iteration 140 | Train Loss  0.0635 | Classifier Accuracy 96.88
# Iteration 160 | Train Loss  0.1786 | Classifier Accuracy 92.19
# Iteration 180 | Train Loss  0.0412 | Classifier Accuracy 98.44
# Iteration 200 | Train Loss  0.1535 | Classifier Accuracy 95.31
# Iteration 220 | Train Loss  0.0965 | Classifier Accuracy 93.75
#
# [Summary] Elapsed time : 1 m 46 s
# Train Loss Mean 0.1051 | Accuracy 95.85
# Valid Loss Mean 0.4575 | Accuracy 85.25
#
#  ====================== epoch 13 ======================
# Iteration   0 | Train Loss  0.0704 | Classifier Accuracy 98.44
# Iteration  20 | Train Loss  0.0584 | Classifier Accuracy 98.44
# Iteration  40 | Train Loss  0.0634 | Classifier Accuracy 96.88
# Iteration  60 | Train Loss  0.0630 | Classifier Accuracy 98.44
# Iteration  80 | Train Loss  0.1827 | Classifier Accuracy 93.75
# Iteration 100 | Train Loss  0.0895 | Classifier Accuracy 96.88
# Iteration 120 | Train Loss  0.0625 | Classifier Accuracy 96.88
# Iteration 140 | Train Loss  0.0670 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.1283 | Classifier Accuracy 95.31
# Iteration 180 | Train Loss  0.1017 | Classifier Accuracy 95.31
# Iteration 200 | Train Loss  0.0640 | Classifier Accuracy 96.88
# Iteration 220 | Train Loss  0.0490 | Classifier Accuracy 98.44
#
# [Summary] Elapsed time : 1 m 46 s
# Train Loss Mean 0.0919 | Accuracy 96.39
# Valid Loss Mean 0.3431 | Accuracy 87.84
#
#  ====================== epoch 14 ======================
# Iteration   0 | Train Loss  0.0452 | Classifier Accuracy 100.00
# Iteration  20 | Train Loss  0.0830 | Classifier Accuracy 95.31
# Iteration  40 | Train Loss  0.0538 | Classifier Accuracy 96.88
# Iteration  60 | Train Loss  0.0783 | Classifier Accuracy 96.88
# Iteration  80 | Train Loss  0.1323 | Classifier Accuracy 95.31
# Iteration 100 | Train Loss  0.0664 | Classifier Accuracy 96.88
# Iteration 120 | Train Loss  0.1132 | Classifier Accuracy 95.31
# Iteration 140 | Train Loss  0.0882 | Classifier Accuracy 95.31
# Iteration 160 | Train Loss  0.0087 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0381 | Classifier Accuracy 98.44
# Iteration 200 | Train Loss  0.1545 | Classifier Accuracy 95.31
# Iteration 220 | Train Loss  0.0716 | Classifier Accuracy 98.44
#
# [Summary] Elapsed time : 1 m 45 s
# Train Loss Mean 0.0734 | Accuracy 97.05
# Valid Loss Mean 0.4272 | Accuracy 87.82
#
#  ====================== epoch 15 ======================
# Iteration   0 | Train Loss  0.1169 | Classifier Accuracy 95.31
# Iteration  20 | Train Loss  0.0128 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0195 | Classifier Accuracy 98.44
# Iteration  60 | Train Loss  0.0337 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0475 | Classifier Accuracy 96.88
# Iteration 100 | Train Loss  0.0655 | Classifier Accuracy 96.88
# Iteration 120 | Train Loss  0.1225 | Classifier Accuracy 93.75
# Iteration 140 | Train Loss  0.0729 | Classifier Accuracy 96.88
# Iteration 160 | Train Loss  0.0735 | Classifier Accuracy 95.31
# Iteration 180 | Train Loss  0.0473 | Classifier Accuracy 98.44
# Iteration 200 | Train Loss  0.2591 | Classifier Accuracy 92.19
# Iteration 220 | Train Loss  0.4757 | Classifier Accuracy 78.12
#
# [Summary] Elapsed time : 1 m 45 s
# Train Loss Mean 0.1370 | Accuracy 94.33
# Valid Loss Mean 2.9207 | Accuracy 49.82
#
#  ====================== epoch 16 ======================
# Iteration   0 | Train Loss  0.3250 | Classifier Accuracy 92.19
# Iteration  20 | Train Loss  0.3514 | Classifier Accuracy 85.94
# Iteration  40 | Train Loss  0.2268 | Classifier Accuracy 93.75
# Iteration  60 | Train Loss  0.2801 | Classifier Accuracy 89.06
# Iteration  80 | Train Loss  0.2625 | Classifier Accuracy 89.06
# Iteration 100 | Train Loss  0.1228 | Classifier Accuracy 95.31
# Iteration 120 | Train Loss  0.1146 | Classifier Accuracy 92.19
# Iteration 140 | Train Loss  0.1196 | Classifier Accuracy 95.31
# Iteration 160 | Train Loss  0.1829 | Classifier Accuracy 90.62
# Iteration 180 | Train Loss  0.2647 | Classifier Accuracy 90.62
# Iteration 200 | Train Loss  0.0575 | Classifier Accuracy 98.44
# Iteration 220 | Train Loss  0.2972 | Classifier Accuracy 87.50
#
# [Summary] Elapsed time : 1 m 45 s
# Train Loss Mean 0.1964 | Accuracy 91.91
# Valid Loss Mean 0.3033 | Accuracy 87.03
#
#  ====================== epoch 17 ======================
# Iteration   0 | Train Loss  0.0570 | Classifier Accuracy 98.44
# Iteration  20 | Train Loss  0.0129 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0743 | Classifier Accuracy 96.88
# Iteration  60 | Train Loss  0.0540 | Classifier Accuracy 96.88
# Iteration  80 | Train Loss  0.0852 | Classifier Accuracy 96.88
# Iteration 100 | Train Loss  0.0646 | Classifier Accuracy 95.31
# Iteration 120 | Train Loss  0.0063 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.1187 | Classifier Accuracy 93.75
# Iteration 160 | Train Loss  0.0596 | Classifier Accuracy 96.88
# Iteration 180 | Train Loss  0.0649 | Classifier Accuracy 95.31
# Iteration 200 | Train Loss  0.0286 | Classifier Accuracy 100.00
# Iteration 220 | Train Loss  0.0568 | Classifier Accuracy 98.44
#
# [Summary] Elapsed time : 1 m 45 s
# Train Loss Mean 0.0821 | Accuracy 96.78
# Valid Loss Mean 0.3675 | Accuracy 87.82
#
#  ====================== epoch 18 ======================
# Iteration   0 | Train Loss  0.1053 | Classifier Accuracy 96.88
# Iteration  20 | Train Loss  0.0101 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0089 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.1888 | Classifier Accuracy 95.31
# Iteration  80 | Train Loss  0.1271 | Classifier Accuracy 95.31
# Iteration 100 | Train Loss  0.0157 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0196 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0232 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.0172 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0906 | Classifier Accuracy 95.31
# Iteration 200 | Train Loss  0.0309 | Classifier Accuracy 100.00
# Iteration 220 | Train Loss  0.0347 | Classifier Accuracy 98.44
#
# [Summary] Elapsed time : 1 m 46 s
# Train Loss Mean 0.0517 | Accuracy 97.92
# Valid Loss Mean 0.5670 | Accuracy 85.05
#
#  ====================== epoch 19 ======================
# Iteration   0 | Train Loss  0.0119 | Classifier Accuracy 100.00
# Iteration  20 | Train Loss  0.0611 | Classifier Accuracy 96.88
# Iteration  40 | Train Loss  0.0088 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0830 | Classifier Accuracy 95.31
# Iteration  80 | Train Loss  0.0148 | Classifier Accuracy 100.00
# Iteration 100 | Train Loss  0.0169 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0779 | Classifier Accuracy 96.88
# Iteration 140 | Train Loss  0.0508 | Classifier Accuracy 98.44
# Iteration 160 | Train Loss  0.0178 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0499 | Classifier Accuracy 98.44
# Iteration 200 | Train Loss  0.0698 | Classifier Accuracy 96.88
# Iteration 220 | Train Loss  0.1615 | Classifier Accuracy 92.19
#
# [Summary] Elapsed time : 1 m 46 s
# Train Loss Mean 0.0616 | Accuracy 97.58
# Valid Loss Mean 0.4174 | Accuracy 86.99
#
#  ====================== epoch 20 ======================
# Iteration   0 | Train Loss  0.1617 | Classifier Accuracy 95.31
# Iteration  20 | Train Loss  0.0772 | Classifier Accuracy 95.31
# Iteration  40 | Train Loss  0.1347 | Classifier Accuracy 95.31
# Iteration  60 | Train Loss  0.0226 | Classifier Accuracy 98.44
# Iteration  80 | Train Loss  0.0653 | Classifier Accuracy 96.88
# Iteration 100 | Train Loss  0.1222 | Classifier Accuracy 95.31
# Iteration 120 | Train Loss  0.0531 | Classifier Accuracy 96.88
# Iteration 140 | Train Loss  0.0603 | Classifier Accuracy 96.88
# Iteration 160 | Train Loss  0.0341 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0577 | Classifier Accuracy 96.88
# Iteration 200 | Train Loss  0.0610 | Classifier Accuracy 95.31
# Iteration 220 | Train Loss  0.0862 | Classifier Accuracy 98.44
#
# [Summary] Elapsed time : 1 m 46 s
# Train Loss Mean 0.0611 | Accuracy 97.57
# Valid Loss Mean 0.3535 | Accuracy 89.70
#
#  ====================== epoch 21 ======================
# Iteration   0 | Train Loss  0.0208 | Classifier Accuracy 98.44
# Iteration  20 | Train Loss  0.0221 | Classifier Accuracy 98.44
# Iteration  40 | Train Loss  0.0120 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0526 | Classifier Accuracy 98.44
# Iteration  80 | Train Loss  0.0272 | Classifier Accuracy 98.44
# Iteration 100 | Train Loss  0.0170 | Classifier Accuracy 98.44
# Iteration 120 | Train Loss  0.2022 | Classifier Accuracy 98.44
# Iteration 140 | Train Loss  0.0932 | Classifier Accuracy 96.88
# Iteration 160 | Train Loss  0.0210 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.1024 | Classifier Accuracy 96.88
# Iteration 200 | Train Loss  0.1341 | Classifier Accuracy 95.31
# Iteration 220 | Train Loss  0.1171 | Classifier Accuracy 95.31
#
# [Summary] Elapsed time : 1 m 46 s
# Train Loss Mean 0.0418 | Accuracy 98.20
# Valid Loss Mean 0.3180 | Accuracy 89.44
#
#  ====================== epoch 22 ======================
# Iteration   0 | Train Loss  0.0373 | Classifier Accuracy 98.44
# Iteration  20 | Train Loss  0.0146 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.1614 | Classifier Accuracy 96.88
# Iteration  60 | Train Loss  0.0666 | Classifier Accuracy 95.31
# Iteration  80 | Train Loss  0.0034 | Classifier Accuracy 100.00
# Iteration 100 | Train Loss  0.0747 | Classifier Accuracy 98.44
# Iteration 120 | Train Loss  0.0231 | Classifier Accuracy 98.44
# Iteration 140 | Train Loss  0.0077 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.1009 | Classifier Accuracy 96.88
# Iteration 180 | Train Loss  0.1285 | Classifier Accuracy 96.88
# Iteration 200 | Train Loss  0.0314 | Classifier Accuracy 98.44
# Iteration 220 | Train Loss  0.1168 | Classifier Accuracy 95.31
#
# [Summary] Elapsed time : 1 m 46 s
# Train Loss Mean 0.0487 | Accuracy 97.97
# Valid Loss Mean 0.2993 | Accuracy 89.91
#
#  ====================== epoch 23 ======================
# Iteration   0 | Train Loss  0.0201 | Classifier Accuracy 100.00
# Iteration  20 | Train Loss  0.0201 | Classifier Accuracy 98.44
# Iteration  40 | Train Loss  0.0132 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0159 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0332 | Classifier Accuracy 98.44
# Iteration 100 | Train Loss  0.0038 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0191 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0012 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.0139 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0161 | Classifier Accuracy 100.00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-ff315a1eb304> in <module>()
#      56       loss = F.cross_entropy(scores, targets)
#      57       loss.backward()
# ---> 58       optimizer.step()
#      59
#      60       correct = sum(targets == preds).cpu()
#
# /usr/local/lib/python3.7/dist-packages/torch/optim/lr_scheduler.py in wrapper(*args, **kwargs)
#      63                 instance._step_count += 1
#      64                 wrapped = func.__get__(instance, cls)
# ---> 65                 return wrapped(*args, **kwargs)
#      66
#      67             # Note that the returned function here is no longer a bound method,
#
# /usr/local/lib/python3.7/dist-packages/torch/optim/optimizer.py in wrapper(*args, **kwargs)
#      87                 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#      88                 with torch.autograd.profiler.record_function(profile_name):
# ---> 89                     return func(*args, **kwargs)
#      90             return wrapper
#      91
#
# /usr/local/lib/python3.7/dist-packages/torch_optimizer/radam.py in step(self, closure)
#     132
#     133                 exp_avg_sq.mul_(beta2).addcmul_(grad, grad, value=1 - beta2)
# --> 134                 exp_avg.mul_(beta1).add_(grad, alpha=1 - beta1)
#     135
#     136                 state['step'] += 1
#
# KeyboardInterrupt:

# %% [markdown]
# # XceptionNet

# %%
 #모델 훈련
num_epochs = 40
EARLY_STOPPING_EPOCH = 7
SEED = 42

# cross validation을 적용하기 위한 KFold 생성
from sklearn.model_selection import KFold
kfold = KFold(n_splits=5, shuffle=True, random_state=SEED) #5-fold

xcep_models=[]

#train_df에서 train_index와 valid_index 생성
for fold_index, (train_index, valid_index) in enumerate(kfold.split(train_df),1): #enumerate(,1) 1부터 index시작
  print('[fold: %d' %fold_index)

  #CUDA cahe 초기화
  torch.cuda.empty_cache()

  #train fold, valid fold 분할
  train = train_df.iloc[train_index]
  valid = train_df.iloc[valid_index]

  tr_dataset = FaceDataset(image_label=train, transforms=transforms_tr)
  val_dataset = FaceDataset(image_label=valid, transforms=transforms_val)

  train_loader = DataLoader(tr_dataset, batch_size=64, shuffle=True, num_workers=8)
  valid_loader = DataLoader(val_dataset, batch_size=64, shuffle=True, num_workers=8)

  model = timm.create_model('xception', pretrained=False)
  model.to(device)
  optimizer = optim.RAdam(model.parameters(), lr=0.0015, betas=(0.9,0.999), weight_decay=0)
  lr_sched = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=50)

  #train 시작
  valid_early_stop = 0

  valid_best_loss = float('inf')
  since = time.time()

  final_train_loss = []
  final_train_acc = []
  final_valid_loss = []
  final_valid_acc = []

  for e in range(num_epochs) :
    print(f' ====================== epoch %d ======================' % (e+1) )
    train_loss_list = []
    train_acc_list = []

    # train
    model.train()
    for i, (images, targets) in enumerate(train_loader) : 
      optimizer.zero_grad()
      
      images = images.to(device, dtype)
      targets = targets.to(device, ltype)
    
      scores = model(images)
      _, preds = scores.max(dim=1)

      loss = F.cross_entropy(scores, targets)
      loss.backward()
      optimizer.step()
      
      correct = sum(targets == preds).cpu()
      acc=(correct/64 * 100)

      train_loss_list.append(loss)
      train_acc_list.append(acc)

      if i % 20 == 0 :
        print(f'Iteration %3.d | Train Loss  %.4f | Classifier Accuracy %2.2f' % (i, loss, acc))

    train_mean_loss = np.mean(train_loss_list, dtype="float64")
    train_mean_acc = np.mean(train_acc_list, dtype="float64")

    final_train_loss.append(train_mean_loss)
    final_train_acc.append(train_mean_acc)
    
    epoch_time = time.time() - since
    since = time.time()

    print('')
    print(f'[Summary] Elapsed time : %.0f m %.0f s' % (epoch_time // 60, epoch_time % 60))
    print(f'Train Loss Mean %.4f | Accuracy %2.2f ' % (train_mean_loss, train_mean_acc) )

    # validation 
    model.eval()
    valid_loss_list = []
    valid_acc_list = []
    for i, (images, targets) in enumerate(valid_loader) : 
      optimizer.zero_grad()
      images = images.to(device=device, dtype=dtype)
      targets = targets.to(device=device, dtype=ltype)

      with torch.no_grad():
        scores = model(images)
        loss = torch.nn.functional.cross_entropy(scores, targets)
        _, preds = scores.max(dim=1)
      
      correct = sum(targets == preds).cpu()
      acc=(correct/64 * 100)

      valid_loss_list.append(loss)
      valid_acc_list.append(acc)
  
    val_mean_loss = np.mean(valid_loss_list, dtype="float64")
    val_mean_acc = np.mean(valid_acc_list, dtype="float64")

    final_valid_loss.append(val_mean_loss)
    final_valid_acc.append(val_mean_acc)

    print(f'Valid Loss Mean %.4f | Accuracy %2.2f ' % (val_mean_loss, val_mean_acc) )
    print('')

    if val_mean_loss < valid_best_loss:
      valid_best_loss = val_mean_loss
      valid_early_stop = 0
      best_model = model
      if (e+1) == num_epochs:
        xcep_models.append(best_model)

    else:
      # early stopping    
      valid_early_stop += 1
      if valid_early_stop >= EARLY_STOPPING_EPOCH:
        print("EARLY STOPPING!!")
        xcep_models.append(best_model)
        break

    lr_sched.step()

# %% [markdown]
# ## 추론

# %%
submission = pd.read_csv("./face_image/submission_v1.1.csv")
submission.head()

# %%
test_dataset = TestDataset(submission['image'], transforms_val)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False, num_workers=8) #num_workers 2에서 8로 변경

# %% [markdown]
# # SoftMax

# %%
import numpy as np

def softmax_0(score0, score1):
  exp_a0 = np.exp(score0)
  exp_a1 = np.exp(score1)
  sum_exp=exp_a0+exp_a1
  y=exp_a0 / sum_exp
  return y

# %%
scores_result=[]
prob_zero=[0 for _ in range(5000)]

model_list=[xcep_models[0],xcep_models[1],xcep_models[2],xcep_models[3],xcep_models[4],
            resnet_models[0],resnet_models[1],resnet_models[2],resnet_models[3],resnet_models[4],
            effi_models[0], effi_models[1], effi_models[2],effi_models[3]]

for i in range(14): #model 개수만큼 for문 돌리기
  predictions = []
  files = []
  score_list=[]

  with torch.no_grad():
    for img_names, images in test_loader:
      images = images.to(device=device, dtype=dtype)
      scores = model_list[i](images)
      _, preds = scores.max(dim=1)
      
      files.extend(img_names)
      predictions.extend(preds.squeeze(0).detach().cpu().numpy())
      score_list.extend(scores.squeeze(0).detach().cpu().numpy())

  for i, score in enumerate(score_list):
    prob_zero[i]+=softmax_0(score[0],score[1])

# %%
for i in range(5000):
  prob_zero[i]/=14  #model 개수로 나눈다
  prob_zero[i]=(prob_zero[i]<0.5)*1

# %%
df = pd.DataFrame(columns=submission.columns)
df['image'] = files
df['label'] = prob_zero
df.head(30)

# %%
df.to_csv("./submission_group5.csv", index=False)
